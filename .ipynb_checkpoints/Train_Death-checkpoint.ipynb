# %%
days_to_check=[30,60,90,120,180] #YOU CAN CHANGE THIS IF YOU WANT TO TRAIN MORE MODELS

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import pickle
#LOAD DATA in a DataFrame
bucket='hf-initial-data'
folder_name='processed'
data_key = 'HF_AWS_Final.csv'
data_location = 's3://{}/{}/{}'.format(bucket, folder_name, data_key)

df = pd.read_csv(data_location)

#Enable full print of dataframe just to see everything instead of only 10 columns
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (188,259,265,289,325,331,346,375,377,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,495,496,497,498,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,603,604,605,606,607,608,609,610,611,612,613,614,615,616,617,618,619,620,621,622) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Allotting Imputation Methods

# %%
df.dtypes
# Out:
# Unnamed: 0                                                int64
# pre_internal_VisitAnonId                                  int64
# pre_internal_PatientAnonId                                int64
# pre_internal_MrCareProviderAnonId                         int64
# pre_internal_MrCareProviderService                       object
# pre_internal_Gender                                       int64
# pre_internal_Age                                          int64
# pre_internal_HealthAuthorityCode                         object
# pre_internal_FacilityCode                                object
# pre_internal_AdmissionDate                               object
# pre_internal_DischargeDate                               object
# pre_internal_MRDx                                        object
# pre_internal_MR_Unit                                     object
# pre_internal_FiscalPeriod                                object
# pre_internal_FiscalYear                                   int64
# pre_internal_LOS                                          int64
# pre_internal_ALOS                                         int64
# pre_internal_ELOS                                       float64
# pre_internal_ALOS_ELOS                                  float64
# pre_internal_DischargeDisposition                        object
# pre_internal_Palliative                                 float64
# pre_internal_AuditStatus                                 object
# pre_internal_ExclusionReason                            float64
# pre_internal_ExclusionPlannedIntervention               float64
# pre_internal_hx_CKD                                     float64
# pre_internal_hx_COPD                                    float64
# pre_internal_hx_Asthma                                  float64
# pre_internal_hx_Malignancy                              float64
# pre_internal_hx_LiverDisease                            float64
# pre_internal_hx_Anemia                                  float64
# pre_internal_hx_PUD                                     float64
# pre_internal_hx_Dementia                                float64
# pre_internal_hx_MI                                      float64
# pre_internal_hx_Angina                                  float64
# pre_internal_hx_CABG                                    float64
# pre_internal_hx_PCI                                     float64
# pre_internal_hx_CVA                                     float64
# pre_internal_hx_TIA                                     float64
# pre_internal_hx_PAD                                     float64
# pre_internal_hx_DM                                      float64
# pre_internal_hx_HTN                                     float64
# pre_internal_hx_Smoking                                  object
# pre_internal_hx_AlcoholExcess                           float64
# pre_internal_hx_AF                                      float64
# pre_internal_hx_AFL                                     float64
# pre_internal_hx_VTE                                     float64
# pre_internal_hx_ExistingHF                              float64
# pre_internal_hx_HF_Hospitalization                      float64
# pre_internal_hx_HeartTransplant                         float64
# pre_internal_Dyspnea                                     object
# pre_internal_Orthopnea                                  float64
# pre_internal_PND                                        float64
# pre_internal_Swelling                                   float64
# pre_internal_Fatigue                                    float64
# pre_internal_Syncope                                    float64
# pre_internal_NYHA                                        object
# pre_internal_ChestPain                                  float64
# pre_internal_Exam_Weight                                float64
# pre_internal_Exam_WeightNotRecorded                       int64
# pre_internal_Exam_HR                                    float64
# pre_internal_Exam_SBP                                   float64
# pre_internal_Exam_DBP                                   float64
# pre_internal_Exam_RespiratoryRate                       float64
# pre_internal_Exam_OxygenSaturation                      float64
# pre_internal_Exam_ReceivingOxygen                       float64
# pre_internal_MedDisch_ACEI                              float64
# pre_internal_MedDisch_ACEI_NoReason                      object
# pre_internal_MedDisch_ACEI_Name                          object
# pre_internal_MedDisch_ACEI_Dose                         float64
# pre_internal_MedDisch_ACEI_Contraindication              object
# pre_internal_MedDisch_ARB                               float64
# pre_internal_MedDisch_ARB_NoReason                       object
# pre_internal_MedDisch_ARB_Name                           object
# pre_internal_MedDisch_ARB_Dose                          float64
# pre_internal_MedDisch_ARB_Contraindication               object
# pre_internal_MedDisch_BB                                float64
# pre_internal_MedDisch_BB_NoReason                        object
# pre_internal_MedDisch_BB_Name                            object
# pre_internal_MedDisch_BB_Dose                           float64
# pre_internal_MedDisch_BB_Contraindication                object
# pre_internal_MedDisch_MRA                               float64
# pre_internal_MedDisch_MRA_NoReason                       object
# pre_internal_MedDisch_MRA_Name                           object
# pre_internal_MedDisch_MRA_Dose                          float64
# pre_internal_MedDisch_MRA_Contraindication               object
# pre_internal_MedDisch_ARNI                              float64
# pre_internal_MedDisch_ARNI_NoReason                      object
# pre_internal_MedDisch_ARNI_Contraindication              object
# pre_internal_MedDisch_ARNI_Dose                         float64
# pre_internal_MedDisch_DIG                               float64
# pre_internal_MedDisch_DIG_NoReason                      float64
# pre_internal_MedDisch_DIG_Dose                          float64
# pre_internal_MedDisch_Hydralazine                       float64
# pre_internal_MedDisch_HydralazineDose                   float64
# pre_internal_MedDisch_NitrateOralOrPatch                float64
# pre_internal_MedDisch_LoopDiuretic                      float64
# pre_internal_MedDisch_LoopDiureticName                   object
# pre_internal_MedDisch_LoopDiureticDose                  float64
# pre_internal_MedDisch_ThiazideDiuretic                  float64
# pre_internal_MedDisch_ThiazideDiureticDose              float64
# pre_internal_MedDisch_ASA                               float64
# pre_internal_MedDisch_ASA_NoReason                      float64
# pre_internal_MedDisch_ASA_Dose                          float64
# pre_internal_MedDisch_OtherAntiplatelet                 float64
# pre_internal_MedDisch_OtherAntiplateletNoReason         float64
# pre_internal_MedDisch_OtherAntiplateletDose             float64
# pre_internal_MedDisch_Heparin                           float64
# pre_internal_MedDisch_Warfarin                          float64
# pre_internal_MedDisch_WarfarinNoReason                   object
# pre_internal_MedDisch_WarfarinContraindication           object
# pre_internal_MedDisch_WarfarinDose                      float64
# pre_internal_MedDisch_NOAC                              float64
# pre_internal_MedDisch_NOAC_NoReason                      object
# pre_internal_MedDisch_NOAC_Contraindication              object
# pre_internal_MedDisch_NOAC_Name                          object
# pre_internal_MedDisch_NOAC_Dose                         float64
# pre_internal_MedDisch_NSAID                             float64
# pre_internal_MedDisch_NSAID_Dose                        float64
# pre_internal_MedDisch_Amiodarone                        float64
# pre_internal_MedDisch_AmiodaroneDose                    float64
# pre_internal_MedDisch_CCB                               float64
# pre_internal_MedDisch_CCB_Dose                          float64
# pre_internal_MedDisch_Statins                           float64
# pre_internal_MedDisch_StatinsDose                       float64
# pre_internal_Pacemaker                                  float64
# pre_internal_PacemakerNoReason                           object
# pre_internal_PacemakerType                               object
# pre_internal_Defibrillator                              float64
# pre_internal_DefibrillatorNoReason                       object
# pre_internal_DefibrillatorType                           object
# pre_internal_Lab_BNP_Count                                int64
# pre_internal_Lab_BNP_UpperRefLimit                       object
# pre_internal_Lab_BNP_LowerRefLimit                      float64
# pre_internal_Lab_NT_proBNP_Count                          int64
# pre_internal_Lab_NT_proBNP_UpperRefLimit                 object
# pre_internal_Lab_NT_proBNP_LowerRefLimit                float64
# pre_internal_Lab_TroponinI_Count                          int64
# pre_internal_Lab_TroponinI_UpperRefLimit                 object
# pre_internal_Lab_TroponinI_LowerRefLimit                float64
# pre_internal_Lab_TroponinT_Count                          int64
# pre_internal_Lab_TroponinT_UpperRefLimit                 object
# pre_internal_Lab_TroponinT_LowerRefLimit                float64
# pre_internal_Lab_Cr_Count                                 int64
# pre_internal_Lab_Cr_UpperRefLimit                       float64
# pre_internal_Lab_Cr_LowerRefLimit                       float64
# pre_internal_Lab_EGFR_Count                               int64
# pre_internal_Lab_EGFR_UpperRefLimit                     float64
# pre_internal_Lab_EGFR_LowerRefLimit                      object
# pre_internal_Lab_Ur_Count                                 int64
# pre_internal_Lab_Ur_UpperRefLimit                       float64
# pre_internal_Lab_Ur_LowerRefLimit                       float64
# pre_internal_Lab_Na_Count                                 int64
# pre_internal_Lab_Na_UpperRefLimit                       float64
# pre_internal_Lab_Na_LowerRefLimit                       float64
# pre_internal_Lab_K_Count                                  int64
# pre_internal_Lab_K_UpperRefLimit                        float64
# pre_internal_Lab_K_LowerRefLimit                        float64
# pre_internal_Lab_Hb_Count                                 int64
# pre_internal_Lab_Hb_UpperRefLimit                       float64
# pre_internal_Lab_Hb_LowerRefLimit                       float64
# pre_internal_Lab_MCV_Count                                int64
# pre_internal_Lab_MCV_UpperRefLimit                      float64
# pre_internal_Lab_MCV_LowerRefLimit                      float64
# pre_internal_Lab_WBC_Count                                int64
# pre_internal_Lab_WBC_UpperRefLimit                      float64
# pre_internal_Lab_WBC_LowerRefLimit                      float64
# pre_internal_Lab_Platelets_Count                          int64
# pre_internal_Lab_Platelets_UpperRefLimit                float64
# pre_internal_Lab_Platelets_LowerRefLimit                float64
# pre_internal_Lab_INR_Count                                int64
# pre_internal_Lab_INR_UpperRefLimit                      float64
# pre_internal_Lab_INR_LowerRefLimit                      float64
# pre_internal_Lab_HbA1C_Count                              int64
# pre_internal_Lab_HbA1C_UpperRefLimit                    float64
# pre_internal_Lab_HbA1C_LowerRefLimit                    float64
# pre_internal_Lab_Iron_Count                               int64
# pre_internal_Lab_Iron_UpperRefLimit                     float64
# pre_internal_Lab_Iron_LowerRefLimit                     float64
# pre_internal_Lab_Ferritin_Count                           int64
# pre_internal_Lab_Ferritin_UpperRefLimit                 float64
# pre_internal_Lab_Ferritin_LowerRefLimit                 float64
# pre_internal_Lab_Bilirubin_Count                          int64
# pre_internal_Lab_Bilirubin_UpperRefLimit                 object
# pre_internal_Lab_Bilirubin_LowerRefLimit                float64
# pre_internal_Lab_AST_Count                                int64
# pre_internal_Lab_AST_UpperRefLimit                      float64
# pre_internal_Lab_AST_LowerRefLimit                      float64
# pre_internal_Lab_ALT_Count                                int64
# pre_internal_Lab_ALT_UpperRefLimit                       object
# pre_internal_Lab_ALT_LowerRefLimit                      float64
# pre_internal_Lab_ALP_Count                                int64
# pre_internal_Lab_ALP_UpperRefLimit                      float64
# pre_internal_Lab_ALP_LowerRefLimit                      float64
# pre_internal_Lab_GGT_Count                                int64
# pre_internal_Lab_GGT_UpperRefLimit                       object
# pre_internal_Lab_GGT_LowerRefLimit                      float64
# pre_internal_Lab_Alb_Count                                int64
# pre_internal_Lab_Alb_UpperRefLimit                      float64
# pre_internal_Lab_Alb_LowerRefLimit                      float64
# pre_internal_Lab_TotalCholesterol_Count                   int64
# pre_internal_Lab_TotalCholesterol_UpperRefLimit          object
# pre_internal_Lab_TotalCholesterol_LowerRefLimit         float64
# pre_internal_Lab_LDL_Cholesterol_Count                    int64
# pre_internal_Lab_LDL_Cholesterol_UpperRefLimit           object
# pre_internal_Lab_LDL_Cholesterol_LowerRefLimit          float64
# pre_internal_Lab_UricAcid_Count                           int64
# pre_internal_Lab_UricAcid_UpperRefLimit                 float64
# pre_internal_Lab_UricAcid_LowerRefLimit                 float64
# pre_internal_LabAdm_BNP                                  object
# pre_internal_LabAdm_BNP_Hours                           float64
# pre_internal_LabAdm_BNP_AbnormalityCode                  object
# pre_internal_LabAdm_NT_proBNP                            object
# pre_internal_LabAdm_NT_proBNP_Hours                     float64
# pre_internal_LabAdm_NT_proBNP_AbnormalityCode            object
# pre_internal_LabAdm_TroponinI                            object
# pre_internal_LabAdm_TroponinI_Hours                     float64
# pre_internal_LabAdm_TroponinI_AbnormalityCode            object
# pre_internal_LabAdm_TroponinT                            object
# pre_internal_LabAdm_TroponinT_Hours                     float64
# pre_internal_LabAdm_TroponinT_AbnormalityCode            object
# pre_internal_LabAdm_Cr                                  float64
# pre_internal_LabAdm_Cr_Hours                            float64
# pre_internal_LabAdm_Cr_AbnormalityCode                   object
# pre_internal_LabAdm_EGFR                                 object
# pre_internal_LabAdm_EGFR_Hours                          float64
# pre_internal_LabAdm_EGFR_AbnormalityCode                 object
# pre_internal_LabAdm_Ur                                  float64
# pre_internal_LabAdm_Ur_Hours                            float64
# pre_internal_LabAdm_Ur_AbnormalityCode                   object
# pre_internal_LabAdm_Na                                  float64
# pre_internal_LabAdm_Na_Hours                            float64
# pre_internal_LabAdm_Na_AbnormalityCode                   object
# pre_internal_LabAdm_K                                   float64
# pre_internal_LabAdm_K_Hours                             float64
# pre_internal_LabAdm_K_AbnormalityCode                    object
# pre_internal_LabAdm_Hb                                  float64
# pre_internal_LabAdm_Hb_Hours                            float64
# pre_internal_LabAdm_Hb_AbnormalityCode                   object
# pre_internal_LabAdm_MCV                                 float64
# pre_internal_LabAdm_MCV_Hours                           float64
# pre_internal_LabAdm_MCV_AbnormalityCode                  object
# pre_internal_LabAdm_WBC                                 float64
# pre_internal_LabAdm_WBC_Hours                           float64
# pre_internal_LabAdm_WBC_AbnormalityCode                  object
# pre_internal_LabAdm_Platelets                           float64
# pre_internal_LabAdm_Platelets_Hours                     float64
# pre_internal_LabAdm_Platelets_AbnormalityCode            object
# pre_internal_LabAdm_INR                                  object
# pre_internal_LabAdm_INR_Hours                           float64
# pre_internal_LabAdm_INR_AbnormalityCode                  object
# pre_internal_LabAdm_HbA1C                               float64
# pre_internal_LabAdm_HbA1C_Hours                         float64
# pre_internal_LabAdm_HbA1C_AbnormalityCode                object
# pre_internal_LabAdm_Iron                                float64
# pre_internal_LabAdm_Iron_Hours                          float64
# pre_internal_LabAdm_Iron_AbnormalityCode                 object
# pre_internal_LabAdm_Ferritin                            float64
# pre_internal_LabAdm_Ferritin_Hours                      float64
# pre_internal_LabAdm_Ferritin_AbnormalityCode             object
# pre_internal_LabAdm_Bilirubin                            object
# pre_internal_LabAdm_Bilirubin_Hours                     float64
# pre_internal_LabAdm_Bilirubin_AbnormalityCode            object
# pre_internal_LabAdm_AST                                 float64
# pre_internal_LabAdm_AST_Hours                           float64
# pre_internal_LabAdm_AST_AbnormalityCode                  object
# pre_internal_LabAdm_ALT                                  object
# pre_internal_LabAdm_ALT_Hours                           float64
# pre_internal_LabAdm_ALT_AbnormalityCode                  object
# pre_internal_LabAdm_ALP                                 float64
# pre_internal_LabAdm_ALP_Hours                           float64
# pre_internal_LabAdm_ALP_AbnormalityCode                  object
# pre_internal_LabAdm_GGT                                 float64
# pre_internal_LabAdm_GGT_Hours                           float64
# pre_internal_LabAdm_GGT_AbnormalityCode                  object
# pre_internal_LabAdm_Alb                                 float64
# pre_internal_LabAdm_Alb_Hours                           float64
# pre_internal_LabAdm_Alb_AbnormalityCode                  object
# pre_internal_LabAdm_TotalCholesterol                    float64
# pre_internal_LabAdm_TotalCholesterol_Hours              float64
# pre_internal_LabAdm_TotalCholesterol_AbnormalityCode     object
# pre_internal_LabAdm_LDL_Cholesterol                     float64
# pre_internal_LabAdm_LDL_Cholesterol_Hours               float64
# pre_internal_LabAdm_LDL_Cholesterol_AbnormalityCode      object
# pre_internal_LabAdm_UricAcid                            float64
# pre_internal_LabAdm_UricAcid_Hours                      float64
# pre_internal_LabAdm_UricAcid_AbnormalityCode             object
# pre_internal_LabDisch_Cr                                float64
# pre_internal_LabDisch_Cr_Hours                          float64
# pre_internal_LabDisch_Cr_AbnormalityCode                 object
# pre_internal_LabDisch_EGFR                               object
# pre_internal_LabDisch_EGFR_Hours                        float64
# pre_internal_LabDisch_EGFR_AbnormalityCode               object
# pre_internal_LabDisch_Ur                                float64
# pre_internal_LabDisch_Ur_Hours                          float64
# pre_internal_LabDisch_Ur_AbnormalityCode                 object
# pre_internal_LabDisch_Na                                float64
# pre_internal_LabDisch_Na_Hours                          float64
# pre_internal_LabDisch_Na_AbnormalityCode                 object
# pre_internal_LabDisch_K                                 float64
# pre_internal_LabDisch_K_Hours                           float64
# pre_internal_LabDisch_K_AbnormalityCode                  object
# pre_internal_LabDisch_Hb                                float64
# pre_internal_LabDisch_Hb_Hours                          float64
# pre_internal_LabDisch_Hb_AbnormalityCode                 object
# pre_internal_LabDisch_MCV                               float64
# pre_internal_LabDisch_MCV_Hours                         float64
# pre_internal_LabDisch_MCV_AbnormalityCode                object
# pre_internal_LabDisch_WBC                               float64
# pre_internal_LabDisch_WBC_Hours                         float64
# pre_internal_LabDisch_WBC_AbnormalityCode                object
# pre_internal_LabDisch_Platelets                         float64
# pre_internal_LabDisch_Platelets_Hours                   float64
# pre_internal_LabDisch_Platelets_AbnormalityCode          object
# pre_internal_LabDisch_INR                               float64
# pre_internal_LabDisch_INR_Hours                         float64
# pre_internal_LabDisch_INR_AbnormalityCode                object
# pre_internal_LabDisch_HbA1C                             float64
# pre_internal_LabDisch_HbA1C_Hours                       float64
# pre_internal_LabDisch_HbA1C_AbnormalityCode              object
# pre_internal_LabDisch_Iron                              float64
# pre_internal_LabDisch_Iron_Hours                        float64
# pre_internal_LabDisch_Iron_AbnormalityCode               object
# pre_internal_LabDisch_Ferritin                          float64
# pre_internal_LabDisch_Ferritin_Hours                    float64
# pre_internal_LabDisch_Ferritin_AbnormalityCode           object
# pre_internal_LabDisch_Bilirubin                          object
# pre_internal_LabDisch_Bilirubin_Hours                   float64
# pre_internal_LabDisch_Bilirubin_AbnormalityCode          object
# pre_internal_LabDisch_AST                               float64
# pre_internal_LabDisch_AST_Hours                         float64
# pre_internal_LabDisch_AST_AbnormalityCode                object
# pre_internal_LabDisch_ALT                                object
# pre_internal_LabDisch_ALT_Hours                         float64
# pre_internal_LabDisch_ALT_AbnormalityCode                object
# pre_internal_LabDisch_ALP                               float64
# pre_internal_LabDisch_ALP_Hours                         float64
# pre_internal_LabDisch_ALP_AbnormalityCode                object
# pre_internal_LabDisch_GGT                               float64
# pre_internal_LabDisch_GGT_Hours                         float64
# pre_internal_LabDisch_GGT_AbnormalityCode                object
# pre_internal_LabDisch_Alb                               float64
# pre_internal_LabDisch_Alb_Hours                         float64
# pre_internal_LabDisch_Alb_AbnormalityCode                object
# pre_internal_LabDisch_UricAcid                          float64
# pre_internal_LabDisch_UricAcid_Hours                    float64
# pre_internal_LabDisch_UricAcid_AbnormalityCode           object
# pre_internal_ECG                                         object
# pre_internal_ECG_HR                                     float64
# pre_internal_ECG_Rhythm                                  object
# pre_internal_ECG_QRS_Duration                           float64
# pre_internal_ECG_QRS_Morphology                          object
# pre_internal_ECG_AV_Block                                object
# pre_internal_ECG_PR_Interval                            float64
# pre_internal_ECG_QT_Interval                            float64
# pre_internal_ECG_AFL                                    float64
# pre_internal_Imaging                                      int64
# pre_internal_Imaging_TechnicalDifficulty                float64
# pre_internal_Imaging_EF_Modality                         object
# pre_internal_Imaging_LVEF                               float64
# pre_internal_Imaging_LVEF_Date                           object
# pre_internal_Imaging_LVEF_Year                          float64
# pre_internal_Imaging_DiastolicDysfunction                object
# pre_internal_Imaging_MR                                  object
# pre_internal_Imaging_AS                                  object
# pre_internal_Imaging_OtherValveDisease                  float64
# pre_internal_AdmissionUnitCode                           object
# pre_internal_DischargeUnitCode                           object
# pre_internal_InpatientOrderSet                          float64
# pre_internal_HeartFailureTeachingRecord                  object
# pre_internal_DischargeGuidelinesForHeartFailure          object
# pre_internal_HeartFailureDischargeInstructions           object
# pre_internal_DischargeMedRec                            float64
# pre_internal_DischargeRxGiven                           float64
# pre_internal_FollowUpAppointment                        float64
# pre_internal_Death                                      float64
# pre_internal_DeathDate                                   object
# pre_internal_DeathFSA                                   float64
# pre_internal_DeathCause                                  object
# pre_internal_DeathInHospital                            float64
# pre_internal_Hospitalization                            float64
# pre_internal_HospitalizationDate                        float64
# pre_internal_HospitalizationFacility                    float64
# pre_internal_HospitalizationCause                       float64
# pre_internal_ECG_Diagnosis                              float64
# pre_internal_ETL_Labs                                     int64
# pre_internal_ETL_Hx                                       int64
# pre_internal_ETL_ECG                                      int64
# pre_CSBC_pre_diag_date                                   object
# pre_CSBC_pre_diag_flag                                  float64
# pre_CSBC_pre_PCI_date                                    object
# pre_CSBC_pre_pci_flag                                   float64
# pre_CSBC_pre_CABG_date                                   object
# pre_CSBC_pre_cabg_flag                                  float64
# pre_CSBC_pre_valve_date                                  object
# pre_CSBC_pre_valve_flag                                 float64
# pre_CSBC_pre_ablation_date                               object
# pre_CSBC_pre_ablation_flag                              float64
# pre_CSBC_pre_PM_date                                     object
# pre_CSBC_pre_PM_flag                                    float64
# pre_CSBC_pre_ICD_date                                    object
# pre_CSBC_pre_ICD_flag                                   float64
# pre_CSBC_pre_CRT_date                                    object
# pre_CSBC_pre_CRT_flag                                   float64
# post_n_rehosp                                           float64
# post_total_LOS                                          float64
# post_rehosp_flag                                         object
# post_latest_discharge                                    object
# post_DIAG_CODE_1_1                                       object
# post_DIAG_CODE_1_2                                       object
# post_DIAG_CODE_1_3                                       object
# post_DIAG_CODE_1_4                                       object
# post_DIAG_CODE_1_5                                       object
# post_DIAG_CODE_1_6                                       object
# post_DIAG_CODE_1_7                                       object
# post_DIAG_CODE_1_8                                       object
# post_DIAG_CODE_1_9                                       object
# post_DIAG_CODE_1_10                                      object
# post_DIAG_CODE_1_11                                      object
# post_DIAG_CODE_1_12                                      object
# post_DIAG_CODE_1_13                                      object
# post_DIAG_CODE_1_14                                      object
# post_DIAG_CODE_1_15                                      object
# post_DIAG_CODE_1_16                                      object
# post_DIAG_CODE_1_17                                      object
# post_DIAG_CODE_1_18                                      object
# post_DIAG_CODE_1_19                                      object
# post_DIAG_CODE_1_20                                      object
# post_DIAG_CODE_1_21                                      object
# post_DIAG_CODE_1_22                                      object
# post_DIAG_CODE_1_23                                      object
# post_DIAG_CODE_1_24                                      object
# post_DIAG_CODE_1_25                                      object
# post_DIAG_CODE_1_26                                      object
# post_DIAG_CODE_1_27                                      object
# post_DIAG_CODE_1_28                                      object
# post_DIAG_CODE_1_29                                      object
# post_DIAG_CODE_1_30                                      object
# post_DIAG_CODE_1_31                                      object
# post_DIAG_CODE_1_32                                      object
# post_DIAG_CODE_1_33                                      object
# post_DIAG_CODE_1_34                                      object
# post_DIAG_CODE_1_35                                      object
# post_DIAG_CODE_1_36                                      object
# post_DIAG_CODE_1_37                                      object
# post_DIAG_CODE_1_38                                      object
# post_DIAG_CODE_1_39                                      object
# post_DIAG_CODE_1_40                                      object
# post_DIAG_CODE_1_41                                      object
# post_DIAG_CODE_1_42                                      object
# post_DIAG_CODE_1_43                                      object
# post_DIAG_CODE_1_44                                      object
# post_DIAG_CODE_1_45                                      object
# post_DIAG_CODE_1_46                                      object
# post_DIAG_CODE_1_47                                      object
# post_DIAG_CODE_1_48                                      object
# post_DIAG_CODE_1_49                                      object
# post_DIAG_CODE_1_50                                      object
# post_DIAG_CODE_1_51                                      object
# post_DIAG_CODE_1_52                                      object
# post_DIAG_CODE_1_53                                      object
# post_DIAG_CODE_1_54                                      object
# post_ADMISSION_DATE_1                                    object
# post_ADMISSION_DATE_2                                    object
# post_ADMISSION_DATE_3                                    object
# post_ADMISSION_DATE_4                                    object
# post_ADMISSION_DATE_5                                    object
# post_ADMISSION_DATE_6                                    object
# post_ADMISSION_DATE_7                                    object
# post_ADMISSION_DATE_8                                    object
# post_ADMISSION_DATE_9                                    object
# post_ADMISSION_DATE_10                                   object
# post_ADMISSION_DATE_11                                   object
# post_ADMISSION_DATE_12                                   object
# post_ADMISSION_DATE_13                                   object
# post_ADMISSION_DATE_14                                   object
# post_ADMISSION_DATE_15                                   object
# post_ADMISSION_DATE_16                                   object
# post_ADMISSION_DATE_17                                   object
# post_ADMISSION_DATE_18                                   object
# post_ADMISSION_DATE_19                                   object
# post_ADMISSION_DATE_20                                   object
# post_ADMISSION_DATE_21                                   object
# post_ADMISSION_DATE_22                                   object
# post_ADMISSION_DATE_23                                   object
# post_ADMISSION_DATE_24                                   object
# post_ADMISSION_DATE_25                                   object
# post_ADMISSION_DATE_26                                   object
# post_ADMISSION_DATE_27                                   object
# post_ADMISSION_DATE_28                                   object
# post_ADMISSION_DATE_29                                   object
# post_ADMISSION_DATE_30                                   object
# post_ADMISSION_DATE_31                                   object
# post_ADMISSION_DATE_32                                   object
# post_ADMISSION_DATE_33                                   object
# post_ADMISSION_DATE_34                                   object
# post_ADMISSION_DATE_35                                   object
# post_ADMISSION_DATE_36                                   object
# post_ADMISSION_DATE_37                                   object
# post_ADMISSION_DATE_38                                   object
# post_ADMISSION_DATE_39                                   object
# post_ADMISSION_DATE_40                                   object
# post_ADMISSION_DATE_41                                   object
# post_ADMISSION_DATE_42                                   object
# post_ADMISSION_DATE_43                                   object
# post_ADMISSION_DATE_44                                   object
# post_ADMISSION_DATE_45                                   object
# post_ADMISSION_DATE_46                                   object
# post_ADMISSION_DATE_47                                   object
# post_ADMISSION_DATE_48                                   object
# post_ADMISSION_DATE_49                                   object
# post_ADMISSION_DATE_50                                   object
# post_ADMISSION_DATE_51                                   object
# post_ADMISSION_DATE_52                                   object
# post_ADMISSION_DATE_53                                   object
# post_ADMISSION_DATE_54                                   object
# post_INST_CODE_1                                        float64
# post_INST_CODE_2                                        float64
# post_INST_CODE_3                                        float64
# post_INST_CODE_4                                        float64
# post_INST_CODE_5                                        float64
# post_INST_CODE_6                                        float64
# post_INST_CODE_7                                        float64
# post_INST_CODE_8                                        float64
# post_INST_CODE_9                                        float64
# post_INST_CODE_10                                       float64
# post_INST_CODE_11                                       float64
# post_INST_CODE_12                                       float64
# post_INST_CODE_13                                       float64
# post_INST_CODE_14                                       float64
# post_INST_CODE_15                                       float64
# post_INST_CODE_16                                       float64
# post_INST_CODE_17                                       float64
# post_INST_CODE_18                                       float64
# post_INST_CODE_19                                       float64
# post_INST_CODE_20                                       float64
# post_INST_CODE_21                                       float64
# post_INST_CODE_22                                       float64
# post_INST_CODE_23                                       float64
# post_INST_CODE_24                                       float64
# post_INST_CODE_25                                       float64
# post_INST_CODE_26                                       float64
# post_INST_CODE_27                                       float64
# post_INST_CODE_28                                       float64
# post_INST_CODE_29                                       float64
# post_INST_CODE_30                                       float64
# post_INST_CODE_31                                       float64
# post_INST_CODE_32                                       float64
# post_INST_CODE_33                                       float64
# post_INST_CODE_34                                       float64
# post_INST_CODE_35                                       float64
# post_INST_CODE_36                                       float64
# post_INST_CODE_37                                       float64
# post_INST_CODE_38                                       float64
# post_INST_CODE_39                                       float64
# post_INST_CODE_40                                       float64
# post_INST_CODE_41                                       float64
# post_INST_CODE_42                                       float64
# post_INST_CODE_43                                       float64
# post_INST_CODE_44                                       float64
# post_INST_CODE_45                                       float64
# post_INST_CODE_46                                       float64
# post_INST_CODE_47                                       float64
# post_INST_CODE_48                                       float64
# post_INST_CODE_49                                       float64
# post_INST_CODE_50                                       float64
# post_INST_CODE_51                                       float64
# post_INST_CODE_52                                       float64
# post_INST_CODE_53                                       float64
# post_INST_CODE_54                                       float64
# post_hosp_name_1                                         object
# post_hosp_name_2                                         object
# post_hosp_name_3                                         object
# post_hosp_name_4                                         object
# post_hosp_name_5                                         object
# post_hosp_name_6                                         object
# post_hosp_name_7                                         object
# post_hosp_name_8                                         object
# post_hosp_name_9                                         object
# post_hosp_name_10                                        object
# post_hosp_name_11                                        object
# post_hosp_name_12                                        object
# post_hosp_name_13                                        object
# post_hosp_name_14                                        object
# post_hosp_name_15                                        object
# post_hosp_name_16                                        object
# post_hosp_name_17                                        object
# post_hosp_name_18                                        object
# post_hosp_name_19                                        object
# post_hosp_name_20                                        object
# post_hosp_name_21                                        object
# post_hosp_name_22                                        object
# post_hosp_name_23                                        object
# post_hosp_name_24                                        object
# post_hosp_name_25                                        object
# post_hosp_name_26                                        object
# post_hosp_name_27                                        object
# post_hosp_name_28                                        object
# post_hosp_name_29                                        object
# post_hosp_name_30                                        object
# post_hosp_name_31                                        object
# post_hosp_name_32                                        object
# post_hosp_name_33                                        object
# post_hosp_name_34                                        object
# post_hosp_name_35                                        object
# post_hosp_name_36                                        object
# post_hosp_name_37                                        object
# post_hosp_name_38                                        object
# post_hosp_name_39                                        object
# post_hosp_name_40                                        object
# post_hosp_name_41                                        object
# post_hosp_name_42                                        object
# post_hosp_name_43                                        object
# post_hosp_name_44                                        object
# post_hosp_name_45                                        object
# post_hosp_name_46                                        object
# post_hosp_name_47                                        object
# post_hosp_name_48                                        object
# post_hosp_name_49                                        object
# post_hosp_name_50                                        object
# post_hosp_name_51                                        object
# post_hosp_name_52                                        object
# post_hosp_name_53                                        object
# post_hosp_name_54                                        object
# post_LOS_1                                              float64
# post_LOS_2                                              float64
# post_LOS_3                                              float64
# post_LOS_4                                              float64
# post_LOS_5                                              float64
# post_LOS_6                                              float64
# post_LOS_7                                              float64
# post_LOS_8                                              float64
# post_LOS_9                                              float64
# post_LOS_10                                             float64
# post_LOS_11                                             float64
# post_LOS_12                                             float64
# post_LOS_13                                             float64
# post_LOS_14                                             float64
# post_LOS_15                                             float64
# post_LOS_16                                             float64
# post_LOS_17                                             float64
# post_LOS_18                                             float64
# post_LOS_19                                             float64
# post_LOS_20                                             float64
# post_LOS_21                                             float64
# post_LOS_22                                             float64
# post_LOS_23                                             float64
# post_LOS_24                                             float64
# post_LOS_25                                             float64
# post_LOS_26                                             float64
# post_LOS_27                                             float64
# post_LOS_28                                             float64
# post_LOS_29                                             float64
# post_LOS_30                                             float64
# post_LOS_31                                             float64
# post_LOS_32                                             float64
# post_LOS_33                                             float64
# post_LOS_34                                             float64
# post_LOS_35                                             float64
# post_LOS_36                                             float64
# post_LOS_37                                             float64
# post_LOS_38                                             float64
# post_LOS_39                                             float64
# post_LOS_40                                             float64
# post_LOS_41                                             float64
# post_LOS_42                                             float64
# post_LOS_43                                             float64
# post_LOS_44                                             float64
# post_LOS_45                                             float64
# post_LOS_46                                             float64
# post_LOS_47                                             float64
# post_LOS_48                                             float64
# post_LOS_49                                             float64
# post_LOS_50                                             float64
# post_LOS_51                                             float64
# post_LOS_52                                             float64
# post_LOS_53                                             float64
# post_LOS_54                                             float64
# post_Death_date                                          object
# pre_internal_Ramipril Dose                              float64
# pre_internal_Perindopril Dose                           float64
# pre_internal_Lisinopril Dose                            float64
# pre_internal_Enalapril Dose                             float64
# pre_internal_Captopril Dose                             float64
# pre_internal_Trandolapril Dose                          float64
# pre_internal_Quinapril Dose                             float64
# pre_internal_Benazepril Dose                            float64
# pre_internal_Fosinopril Dose                            float64
# pre_internal_Cilazapril Dose                            float64
# pre_internal_Candesartan Dose                           float64
# pre_internal_Valsartan Dose                             float64
# pre_internal_Losartan Dose                              float64
# pre_internal_Irbesartan Dose                            float64
# pre_internal_Telmisartan Dose                           float64
# pre_internal_Carvedilol Dose                            float64
# pre_internal_Bisoprolol Dose                            float64
# pre_internal_Metoprolol Dose                            float64
# pre_internal_Nebivolol Dose                             float64
# pre_internal_Atenolol Dose                              float64
# pre_internal_Sotalol Dose                               float64
# pre_internal_Propranalol Dose                           float64
# pre_internal_Nadolol Dose                               float64
# pre_internal_Acebutolol Dose                            float64
# pre_internal_Labetolol Dose                             float64
# pre_internal_Pindolol Dose                              float64
# pre_internal_Timolol Dose                               float64
# pre_internal_Spironolactone Dose                        float64
# pre_internal_Eplerenone Dose                            float64
# pre_internal_Furosemide Dose                            float64
# pre_internal_Butenamide Dose                            float64
# pre_internal_Torsemide Dose                             float64
# dtype: object

# %%
df['pre_internal_DischargeDate']
# Out:
# 0       2018-07-20
# 1       2015-12-24
# 2       2015-09-11
# 3       2018-05-11
# 4       2015-12-07
# 5       2018-03-19
# 6       2018-10-24
# 7       2017-07-02
# 8       2018-03-07
# 1760    2017-04-10
# 1761    2015-10-06
# 1762    2015-11-10
# 1763    2017-07-07
# 1764    2017-10-04
# 1765    2018-03-23
# 1766    2018-04-27
# 1767    2018-06-06
# 1768    2018-10-01
# 1769    2018-09-07
# 1770    2015-10-16
# 1771    2018-03-23
# 1772    2015-07-17
# 1773    2016-03-09
# 1774    2017-05-08
# 1775    2018-05-28
# 1776    2019-02-13
# 1777    2017-05-13
# 1778    2018-08-04
# 1779    2017-01-05
# 1780    2015-12-17
# 1781    2018-12-19
# 1782    2018-03-16
# 1783    2015-09-09
# 1784    2018-09-25
# 1785    2016-06-27
# 1786    2018-04-12
# 1787    2017-10-16
# 1788    2019-03-14
# 1789    2017-10-25
# 1790    2018-07-20
# 1791    2018-02-27
# 1792    2016-12-16
# 1793    2018-07-12
# 1794    2017-04-28
# 1795    2018-02-06
# 1796    2019-02-22
# 1797    2019-02-17
# 1798    2018-07-23
# 1799    2016-06-10
# 1800    2016-01-16
# 1801    2019-01-14
# 1802    2016-09-17
# 1803    2018-04-13
# 1804    2016-07-05
# 1805    2018-10-23
# 1806    2017-07-21
# 1807    2016-04-24
# 1808    2018-12-23
# 1809    2017-10-06
# 1810    2016-01-24
# 1811    2015-06-12
# 1812    2018-09-01
# 1813    2016-09-08
# 1814    2018-02-10
# 1815    2018-03-23
# 1816    2015-04-10
# 1817    2017-09-29
# 1818    2016-06-10
# 1819    2016-08-04
# 1820    2015-06-11
# 1821    2016-06-09
# 1822    2017-12-20
# 1823    2017-05-19
# 1824    2015-11-08
# 1825    2017-01-18
# 1826    2017-08-08
# 1827    2018-05-04
# 1828    2018-01-19
# 1829    2019-03-19
# 1830    2016-08-19
# 1831    2018-06-28
# 1832    2016-09-13
# 1833    2018-01-14
# 1834    2016-05-10
# 1835    2015-04-24
# 1836    2015-09-22
# 1837    2018-10-24
# 1838    2015-06-19
# 1839    2015-08-24
# 1840    2016-04-16
# 1841    2017-11-24
# 1842    2018-02-03
# 1843    2016-06-03
# Name: pre_internal_DischargeDate, dtype: object

# %%
df.drop(df.columns[df.isna().all()],axis=1,inplace=True)
df.isna().all()
# Out:
# Unnamed: 0                                              False
# pre_internal_VisitAnonId                                False
# pre_internal_PatientAnonId                              False
# pre_internal_MrCareProviderAnonId                       False
# pre_internal_MrCareProviderService                      False
# pre_internal_Gender                                     False
# pre_internal_Age                                        False
# pre_internal_HealthAuthorityCode                        False
# pre_internal_FacilityCode                               False
# pre_internal_AdmissionDate                              False
# pre_internal_DischargeDate                              False
# pre_internal_MRDx                                       False
# pre_internal_MR_Unit                                    False
# pre_internal_FiscalPeriod                               False
# pre_internal_FiscalYear                                 False
# pre_internal_LOS                                        False
# pre_internal_ALOS                                       False
# pre_internal_ELOS                                       False
# pre_internal_ALOS_ELOS                                  False
# pre_internal_DischargeDisposition                       False
# pre_internal_Palliative                                 False
# pre_internal_AuditStatus                                False
# pre_internal_hx_CKD                                     False
# pre_internal_hx_COPD                                    False
# pre_internal_hx_Asthma                                  False
# pre_internal_hx_Malignancy                              False
# pre_internal_hx_LiverDisease                            False
# pre_internal_hx_Anemia                                  False
# pre_internal_hx_PUD                                     False
# pre_internal_hx_Dementia                                False
# pre_internal_hx_MI                                      False
# pre_internal_hx_Angina                                  False
# pre_internal_hx_CABG                                    False
# pre_internal_hx_PCI                                     False
# pre_internal_hx_CVA                                     False
# pre_internal_hx_TIA                                     False
# pre_internal_hx_PAD                                     False
# pre_internal_hx_DM                                      False
# pre_internal_hx_HTN                                     False
# pre_internal_hx_Smoking                                 False
# pre_internal_hx_AlcoholExcess                           False
# pre_internal_hx_AF                                      False
# pre_internal_hx_AFL                                     False
# pre_internal_hx_VTE                                     False
# pre_internal_hx_ExistingHF                              False
# pre_internal_hx_HF_Hospitalization                      False
# pre_internal_hx_HeartTransplant                         False
# pre_internal_Dyspnea                                    False
# pre_internal_Orthopnea                                  False
# pre_internal_PND                                        False
# pre_internal_Swelling                                   False
# pre_internal_Fatigue                                    False
# pre_internal_Syncope                                    False
# pre_internal_NYHA                                       False
# pre_internal_ChestPain                                  False
# pre_internal_Exam_Weight                                False
# pre_internal_Exam_WeightNotRecorded                     False
# pre_internal_Exam_HR                                    False
# pre_internal_Exam_SBP                                   False
# pre_internal_Exam_DBP                                   False
# pre_internal_Exam_RespiratoryRate                       False
# pre_internal_Exam_OxygenSaturation                      False
# pre_internal_Exam_ReceivingOxygen                       False
# pre_internal_MedDisch_ACEI                              False
# pre_internal_MedDisch_ACEI_NoReason                     False
# pre_internal_MedDisch_ACEI_Name                         False
# pre_internal_MedDisch_ACEI_Dose                         False
# pre_internal_MedDisch_ACEI_Contraindication             False
# pre_internal_MedDisch_ARB                               False
# pre_internal_MedDisch_ARB_NoReason                      False
# pre_internal_MedDisch_ARB_Name                          False
# pre_internal_MedDisch_ARB_Dose                          False
# pre_internal_MedDisch_ARB_Contraindication              False
# pre_internal_MedDisch_BB                                False
# pre_internal_MedDisch_BB_NoReason                       False
# pre_internal_MedDisch_BB_Name                           False
# pre_internal_MedDisch_BB_Dose                           False
# pre_internal_MedDisch_BB_Contraindication               False
# pre_internal_MedDisch_MRA                               False
# pre_internal_MedDisch_MRA_NoReason                      False
# pre_internal_MedDisch_MRA_Name                          False
# pre_internal_MedDisch_MRA_Dose                          False
# pre_internal_MedDisch_MRA_Contraindication              False
# pre_internal_MedDisch_ARNI                              False
# pre_internal_MedDisch_ARNI_NoReason                     False
# pre_internal_MedDisch_ARNI_Contraindication             False
# pre_internal_MedDisch_ARNI_Dose                         False
# pre_internal_MedDisch_DIG                               False
# pre_internal_MedDisch_DIG_Dose                          False
# pre_internal_MedDisch_Hydralazine                       False
# pre_internal_MedDisch_NitrateOralOrPatch                False
# pre_internal_MedDisch_LoopDiuretic                      False
# pre_internal_MedDisch_LoopDiureticName                  False
# pre_internal_MedDisch_LoopDiureticDose                  False
# pre_internal_MedDisch_ThiazideDiuretic                  False
# pre_internal_MedDisch_ASA                               False
# pre_internal_MedDisch_OtherAntiplatelet                 False
# pre_internal_MedDisch_Heparin                           False
# pre_internal_MedDisch_Warfarin                          False
# pre_internal_MedDisch_WarfarinNoReason                  False
# pre_internal_MedDisch_WarfarinContraindication          False
# pre_internal_MedDisch_NOAC                              False
# pre_internal_MedDisch_NOAC_NoReason                     False
# pre_internal_MedDisch_NOAC_Contraindication             False
# pre_internal_MedDisch_NOAC_Name                         False
# pre_internal_MedDisch_NSAID                             False
# pre_internal_MedDisch_Amiodarone                        False
# pre_internal_MedDisch_CCB                               False
# pre_internal_MedDisch_Statins                           False
# pre_internal_Pacemaker                                  False
# pre_internal_PacemakerNoReason                          False
# pre_internal_PacemakerType                              False
# pre_internal_Defibrillator                              False
# pre_internal_DefibrillatorNoReason                      False
# pre_internal_DefibrillatorType                          False
# pre_internal_Lab_BNP_Count                              False
# pre_internal_Lab_BNP_UpperRefLimit                      False
# pre_internal_Lab_NT_proBNP_Count                        False
# pre_internal_Lab_NT_proBNP_UpperRefLimit                False
# pre_internal_Lab_TroponinI_Count                        False
# pre_internal_Lab_TroponinI_UpperRefLimit                False
# pre_internal_Lab_TroponinT_Count                        False
# pre_internal_Lab_TroponinT_UpperRefLimit                False
# pre_internal_Lab_Cr_Count                               False
# pre_internal_Lab_Cr_UpperRefLimit                       False
# pre_internal_Lab_Cr_LowerRefLimit                       False
# pre_internal_Lab_EGFR_Count                             False
# pre_internal_Lab_EGFR_LowerRefLimit                     False
# pre_internal_Lab_Ur_Count                               False
# pre_internal_Lab_Ur_UpperRefLimit                       False
# pre_internal_Lab_Ur_LowerRefLimit                       False
# pre_internal_Lab_Na_Count                               False
# pre_internal_Lab_Na_UpperRefLimit                       False
# pre_internal_Lab_Na_LowerRefLimit                       False
# pre_internal_Lab_K_Count                                False
# pre_internal_Lab_K_UpperRefLimit                        False
# pre_internal_Lab_K_LowerRefLimit                        False
# pre_internal_Lab_Hb_Count                               False
# pre_internal_Lab_Hb_UpperRefLimit                       False
# pre_internal_Lab_Hb_LowerRefLimit                       False
# pre_internal_Lab_MCV_Count                              False
# pre_internal_Lab_MCV_UpperRefLimit                      False
# pre_internal_Lab_MCV_LowerRefLimit                      False
# pre_internal_Lab_WBC_Count                              False
# pre_internal_Lab_WBC_UpperRefLimit                      False
# pre_internal_Lab_WBC_LowerRefLimit                      False
# pre_internal_Lab_Platelets_Count                        False
# pre_internal_Lab_Platelets_UpperRefLimit                False
# pre_internal_Lab_Platelets_LowerRefLimit                False
# pre_internal_Lab_INR_Count                              False
# pre_internal_Lab_INR_UpperRefLimit                      False
# pre_internal_Lab_INR_LowerRefLimit                      False
# pre_internal_Lab_HbA1C_Count                            False
# pre_internal_Lab_Iron_Count                             False
# pre_internal_Lab_Iron_UpperRefLimit                     False
# pre_internal_Lab_Iron_LowerRefLimit                     False
# pre_internal_Lab_Ferritin_Count                         False
# pre_internal_Lab_Ferritin_UpperRefLimit                 False
# pre_internal_Lab_Ferritin_LowerRefLimit                 False
# pre_internal_Lab_Bilirubin_Count                        False
# pre_internal_Lab_Bilirubin_UpperRefLimit                False
# pre_internal_Lab_AST_Count                              False
# pre_internal_Lab_AST_UpperRefLimit                      False
# pre_internal_Lab_AST_LowerRefLimit                      False
# pre_internal_Lab_ALT_Count                              False
# pre_internal_Lab_ALT_UpperRefLimit                      False
# pre_internal_Lab_ALT_LowerRefLimit                      False
# pre_internal_Lab_ALP_Count                              False
# pre_internal_Lab_ALP_UpperRefLimit                      False
# pre_internal_Lab_ALP_LowerRefLimit                      False
# pre_internal_Lab_GGT_Count                              False
# pre_internal_Lab_GGT_UpperRefLimit                      False
# pre_internal_Lab_GGT_LowerRefLimit                      False
# pre_internal_Lab_Alb_Count                              False
# pre_internal_Lab_Alb_UpperRefLimit                      False
# pre_internal_Lab_Alb_LowerRefLimit                      False
# pre_internal_Lab_TotalCholesterol_Count                 False
# pre_internal_Lab_TotalCholesterol_UpperRefLimit         False
# pre_internal_Lab_LDL_Cholesterol_Count                  False
# pre_internal_Lab_LDL_Cholesterol_UpperRefLimit          False
# pre_internal_Lab_UricAcid_Count                         False
# pre_internal_Lab_UricAcid_UpperRefLimit                 False
# pre_internal_Lab_UricAcid_LowerRefLimit                 False
# pre_internal_LabAdm_BNP                                 False
# pre_internal_LabAdm_BNP_Hours                           False
# pre_internal_LabAdm_BNP_AbnormalityCode                 False
# pre_internal_LabAdm_NT_proBNP                           False
# pre_internal_LabAdm_NT_proBNP_Hours                     False
# pre_internal_LabAdm_NT_proBNP_AbnormalityCode           False
# pre_internal_LabAdm_TroponinI                           False
# pre_internal_LabAdm_TroponinI_Hours                     False
# pre_internal_LabAdm_TroponinI_AbnormalityCode           False
# pre_internal_LabAdm_TroponinT                           False
# pre_internal_LabAdm_TroponinT_Hours                     False
# pre_internal_LabAdm_TroponinT_AbnormalityCode           False
# pre_internal_LabAdm_Cr                                  False
# pre_internal_LabAdm_Cr_Hours                            False
# pre_internal_LabAdm_Cr_AbnormalityCode                  False
# pre_internal_LabAdm_EGFR                                False
# pre_internal_LabAdm_EGFR_Hours                          False
# pre_internal_LabAdm_EGFR_AbnormalityCode                False
# pre_internal_LabAdm_Ur                                  False
# pre_internal_LabAdm_Ur_Hours                            False
# pre_internal_LabAdm_Ur_AbnormalityCode                  False
# pre_internal_LabAdm_Na                                  False
# pre_internal_LabAdm_Na_Hours                            False
# pre_internal_LabAdm_Na_AbnormalityCode                  False
# pre_internal_LabAdm_K                                   False
# pre_internal_LabAdm_K_Hours                             False
# pre_internal_LabAdm_K_AbnormalityCode                   False
# pre_internal_LabAdm_Hb                                  False
# pre_internal_LabAdm_Hb_Hours                            False
# pre_internal_LabAdm_Hb_AbnormalityCode                  False
# pre_internal_LabAdm_MCV                                 False
# pre_internal_LabAdm_MCV_Hours                           False
# pre_internal_LabAdm_MCV_AbnormalityCode                 False
# pre_internal_LabAdm_WBC                                 False
# pre_internal_LabAdm_WBC_Hours                           False
# pre_internal_LabAdm_WBC_AbnormalityCode                 False
# pre_internal_LabAdm_Platelets                           False
# pre_internal_LabAdm_Platelets_Hours                     False
# pre_internal_LabAdm_Platelets_AbnormalityCode           False
# pre_internal_LabAdm_INR                                 False
# pre_internal_LabAdm_INR_Hours                           False
# pre_internal_LabAdm_INR_AbnormalityCode                 False
# pre_internal_LabAdm_HbA1C                               False
# pre_internal_LabAdm_HbA1C_Hours                         False
# pre_internal_LabAdm_HbA1C_AbnormalityCode               False
# pre_internal_LabAdm_Iron                                False
# pre_internal_LabAdm_Iron_Hours                          False
# pre_internal_LabAdm_Iron_AbnormalityCode                False
# pre_internal_LabAdm_Ferritin                            False
# pre_internal_LabAdm_Ferritin_Hours                      False
# pre_internal_LabAdm_Ferritin_AbnormalityCode            False
# pre_internal_LabAdm_Bilirubin                           False
# pre_internal_LabAdm_Bilirubin_Hours                     False
# pre_internal_LabAdm_Bilirubin_AbnormalityCode           False
# pre_internal_LabAdm_AST                                 False
# pre_internal_LabAdm_AST_Hours                           False
# pre_internal_LabAdm_AST_AbnormalityCode                 False
# pre_internal_LabAdm_ALT                                 False
# pre_internal_LabAdm_ALT_Hours                           False
# pre_internal_LabAdm_ALT_AbnormalityCode                 False
# pre_internal_LabAdm_ALP                                 False
# pre_internal_LabAdm_ALP_Hours                           False
# pre_internal_LabAdm_ALP_AbnormalityCode                 False
# pre_internal_LabAdm_GGT                                 False
# pre_internal_LabAdm_GGT_Hours                           False
# pre_internal_LabAdm_GGT_AbnormalityCode                 False
# pre_internal_LabAdm_Alb                                 False
# pre_internal_LabAdm_Alb_Hours                           False
# pre_internal_LabAdm_Alb_AbnormalityCode                 False
# pre_internal_LabAdm_TotalCholesterol                    False
# pre_internal_LabAdm_TotalCholesterol_Hours              False
# pre_internal_LabAdm_TotalCholesterol_AbnormalityCode    False
# pre_internal_LabAdm_LDL_Cholesterol                     False
# pre_internal_LabAdm_LDL_Cholesterol_Hours               False
# pre_internal_LabAdm_LDL_Cholesterol_AbnormalityCode     False
# pre_internal_LabAdm_UricAcid                            False
# pre_internal_LabAdm_UricAcid_Hours                      False
# pre_internal_LabAdm_UricAcid_AbnormalityCode            False
# pre_internal_LabDisch_Cr                                False
# pre_internal_LabDisch_Cr_Hours                          False
# pre_internal_LabDisch_Cr_AbnormalityCode                False
# pre_internal_LabDisch_EGFR                              False
# pre_internal_LabDisch_EGFR_Hours                        False
# pre_internal_LabDisch_EGFR_AbnormalityCode              False
# pre_internal_LabDisch_Ur                                False
# pre_internal_LabDisch_Ur_Hours                          False
# pre_internal_LabDisch_Ur_AbnormalityCode                False
# pre_internal_LabDisch_Na                                False
# pre_internal_LabDisch_Na_Hours                          False
# pre_internal_LabDisch_Na_AbnormalityCode                False
# pre_internal_LabDisch_K                                 False
# pre_internal_LabDisch_K_Hours                           False
# pre_internal_LabDisch_K_AbnormalityCode                 False
# pre_internal_LabDisch_Hb                                False
# pre_internal_LabDisch_Hb_Hours                          False
# pre_internal_LabDisch_Hb_AbnormalityCode                False
# pre_internal_LabDisch_MCV                               False
# pre_internal_LabDisch_MCV_Hours                         False
# pre_internal_LabDisch_MCV_AbnormalityCode               False
# pre_internal_LabDisch_WBC                               False
# pre_internal_LabDisch_WBC_Hours                         False
# pre_internal_LabDisch_WBC_AbnormalityCode               False
# pre_internal_LabDisch_Platelets                         False
# pre_internal_LabDisch_Platelets_Hours                   False
# pre_internal_LabDisch_Platelets_AbnormalityCode         False
# pre_internal_LabDisch_INR                               False
# pre_internal_LabDisch_INR_Hours                         False
# pre_internal_LabDisch_INR_AbnormalityCode               False
# pre_internal_LabDisch_HbA1C                             False
# pre_internal_LabDisch_HbA1C_Hours                       False
# pre_internal_LabDisch_HbA1C_AbnormalityCode             False
# pre_internal_LabDisch_Iron                              False
# pre_internal_LabDisch_Iron_Hours                        False
# pre_internal_LabDisch_Iron_AbnormalityCode              False
# pre_internal_LabDisch_Ferritin                          False
# pre_internal_LabDisch_Ferritin_Hours                    False
# pre_internal_LabDisch_Ferritin_AbnormalityCode          False
# pre_internal_LabDisch_Bilirubin                         False
# pre_internal_LabDisch_Bilirubin_Hours                   False
# pre_internal_LabDisch_Bilirubin_AbnormalityCode         False
# pre_internal_LabDisch_AST                               False
# pre_internal_LabDisch_AST_Hours                         False
# pre_internal_LabDisch_AST_AbnormalityCode               False
# pre_internal_LabDisch_ALT                               False
# pre_internal_LabDisch_ALT_Hours                         False
# pre_internal_LabDisch_ALT_AbnormalityCode               False
# pre_internal_LabDisch_ALP                               False
# pre_internal_LabDisch_ALP_Hours                         False
# pre_internal_LabDisch_ALP_AbnormalityCode               False
# pre_internal_LabDisch_GGT                               False
# pre_internal_LabDisch_GGT_Hours                         False
# pre_internal_LabDisch_GGT_AbnormalityCode               False
# pre_internal_LabDisch_Alb                               False
# pre_internal_LabDisch_Alb_Hours                         False
# pre_internal_LabDisch_Alb_AbnormalityCode               False
# pre_internal_LabDisch_UricAcid                          False
# pre_internal_LabDisch_UricAcid_Hours                    False
# pre_internal_LabDisch_UricAcid_AbnormalityCode          False
# pre_internal_ECG                                        False
# pre_internal_ECG_HR                                     False
# pre_internal_ECG_Rhythm                                 False
# pre_internal_ECG_QRS_Duration                           False
# pre_internal_ECG_QRS_Morphology                         False
# pre_internal_ECG_AV_Block                               False
# pre_internal_ECG_PR_Interval                            False
# pre_internal_ECG_QT_Interval                            False
# pre_internal_Imaging                                    False
# pre_internal_Imaging_TechnicalDifficulty                False
# pre_internal_Imaging_EF_Modality                        False
# pre_internal_Imaging_LVEF                               False
# pre_internal_Imaging_LVEF_Date                          False
# pre_internal_Imaging_LVEF_Year                          False
# pre_internal_Imaging_DiastolicDysfunction               False
# pre_internal_Imaging_MR                                 False
# pre_internal_Imaging_AS                                 False
# pre_internal_Imaging_OtherValveDisease                  False
# pre_internal_AdmissionUnitCode                          False
# pre_internal_DischargeUnitCode                          False
# pre_internal_InpatientOrderSet                          False
# pre_internal_HeartFailureTeachingRecord                 False
# pre_internal_DischargeGuidelinesForHeartFailure         False
# pre_internal_HeartFailureDischargeInstructions          False
# pre_internal_DischargeMedRec                            False
# pre_internal_DischargeRxGiven                           False
# pre_internal_FollowUpAppointment                        False
# pre_internal_Death                                      False
# pre_internal_DeathDate                                  False
# pre_internal_DeathCause                                 False
# pre_internal_DeathInHospital                            False
# pre_internal_ETL_Labs                                   False
# pre_internal_ETL_Hx                                     False
# pre_internal_ETL_ECG                                    False
# pre_CSBC_pre_diag_date                                  False
# pre_CSBC_pre_diag_flag                                  False
# pre_CSBC_pre_PCI_date                                   False
# pre_CSBC_pre_pci_flag                                   False
# pre_CSBC_pre_CABG_date                                  False
# pre_CSBC_pre_cabg_flag                                  False
# pre_CSBC_pre_valve_date                                 False
# pre_CSBC_pre_valve_flag                                 False
# pre_CSBC_pre_ablation_date                              False
# pre_CSBC_pre_ablation_flag                              False
# pre_CSBC_pre_PM_date                                    False
# pre_CSBC_pre_PM_flag                                    False
# pre_CSBC_pre_ICD_date                                   False
# pre_CSBC_pre_ICD_flag                                   False
# pre_CSBC_pre_CRT_date                                   False
# pre_CSBC_pre_CRT_flag                                   False
# post_n_rehosp                                           False
# post_total_LOS                                          False
# post_rehosp_flag                                        False
# post_latest_discharge                                   False
# post_DIAG_CODE_1_1                                      False
# post_DIAG_CODE_1_2                                      False
# post_DIAG_CODE_1_3                                      False
# post_DIAG_CODE_1_4                                      False
# post_DIAG_CODE_1_5                                      False
# post_DIAG_CODE_1_6                                      False
# post_DIAG_CODE_1_7                                      False
# post_DIAG_CODE_1_8                                      False
# post_DIAG_CODE_1_9                                      False
# post_DIAG_CODE_1_10                                     False
# post_DIAG_CODE_1_11                                     False
# post_DIAG_CODE_1_12                                     False
# post_DIAG_CODE_1_13                                     False
# post_DIAG_CODE_1_14                                     False
# post_DIAG_CODE_1_15                                     False
# post_DIAG_CODE_1_16                                     False
# post_DIAG_CODE_1_17                                     False
# post_DIAG_CODE_1_18                                     False
# post_DIAG_CODE_1_19                                     False
# post_DIAG_CODE_1_20                                     False
# post_DIAG_CODE_1_21                                     False
# post_DIAG_CODE_1_22                                     False
# post_DIAG_CODE_1_23                                     False
# post_DIAG_CODE_1_24                                     False
# post_DIAG_CODE_1_25                                     False
# post_DIAG_CODE_1_26                                     False
# post_DIAG_CODE_1_27                                     False
# post_DIAG_CODE_1_28                                     False
# post_DIAG_CODE_1_29                                     False
# post_DIAG_CODE_1_30                                     False
# post_DIAG_CODE_1_31                                     False
# post_DIAG_CODE_1_32                                     False
# post_DIAG_CODE_1_33                                     False
# post_DIAG_CODE_1_34                                     False
# post_DIAG_CODE_1_35                                     False
# post_DIAG_CODE_1_36                                     False
# post_DIAG_CODE_1_37                                     False
# post_DIAG_CODE_1_38                                     False
# post_DIAG_CODE_1_39                                     False
# post_DIAG_CODE_1_40                                     False
# post_DIAG_CODE_1_41                                     False
# post_DIAG_CODE_1_42                                     False
# post_DIAG_CODE_1_43                                     False
# post_DIAG_CODE_1_44                                     False
# post_DIAG_CODE_1_45                                     False
# post_DIAG_CODE_1_46                                     False
# post_DIAG_CODE_1_47                                     False
# post_DIAG_CODE_1_48                                     False
# post_DIAG_CODE_1_49                                     False
# post_DIAG_CODE_1_50                                     False
# post_DIAG_CODE_1_51                                     False
# post_DIAG_CODE_1_52                                     False
# post_DIAG_CODE_1_53                                     False
# post_DIAG_CODE_1_54                                     False
# post_ADMISSION_DATE_1                                   False
# post_ADMISSION_DATE_2                                   False
# post_ADMISSION_DATE_3                                   False
# post_ADMISSION_DATE_4                                   False
# post_ADMISSION_DATE_5                                   False
# post_ADMISSION_DATE_6                                   False
# post_ADMISSION_DATE_7                                   False
# post_ADMISSION_DATE_8                                   False
# post_ADMISSION_DATE_9                                   False
# post_ADMISSION_DATE_10                                  False
# post_ADMISSION_DATE_11                                  False
# post_ADMISSION_DATE_12                                  False
# post_ADMISSION_DATE_13                                  False
# post_ADMISSION_DATE_14                                  False
# post_ADMISSION_DATE_15                                  False
# post_ADMISSION_DATE_16                                  False
# post_ADMISSION_DATE_17                                  False
# post_ADMISSION_DATE_18                                  False
# post_ADMISSION_DATE_19                                  False
# post_ADMISSION_DATE_20                                  False
# post_ADMISSION_DATE_21                                  False
# post_ADMISSION_DATE_22                                  False
# post_ADMISSION_DATE_23                                  False
# post_ADMISSION_DATE_24                                  False
# post_ADMISSION_DATE_25                                  False
# post_ADMISSION_DATE_26                                  False
# post_ADMISSION_DATE_27                                  False
# post_ADMISSION_DATE_28                                  False
# post_ADMISSION_DATE_29                                  False
# post_ADMISSION_DATE_30                                  False
# post_ADMISSION_DATE_31                                  False
# post_ADMISSION_DATE_32                                  False
# post_ADMISSION_DATE_33                                  False
# post_ADMISSION_DATE_34                                  False
# post_ADMISSION_DATE_35                                  False
# post_ADMISSION_DATE_36                                  False
# post_ADMISSION_DATE_37                                  False
# post_ADMISSION_DATE_38                                  False
# post_ADMISSION_DATE_39                                  False
# post_ADMISSION_DATE_40                                  False
# post_ADMISSION_DATE_41                                  False
# post_ADMISSION_DATE_42                                  False
# post_ADMISSION_DATE_43                                  False
# post_ADMISSION_DATE_44                                  False
# post_ADMISSION_DATE_45                                  False
# post_ADMISSION_DATE_46                                  False
# post_ADMISSION_DATE_47                                  False
# post_ADMISSION_DATE_48                                  False
# post_ADMISSION_DATE_49                                  False
# post_ADMISSION_DATE_50                                  False
# post_ADMISSION_DATE_51                                  False
# post_ADMISSION_DATE_52                                  False
# post_ADMISSION_DATE_53                                  False
# post_ADMISSION_DATE_54                                  False
# post_INST_CODE_1                                        False
# post_INST_CODE_2                                        False
# post_INST_CODE_3                                        False
# post_INST_CODE_4                                        False
# post_INST_CODE_5                                        False
# post_INST_CODE_6                                        False
# post_INST_CODE_7                                        False
# post_INST_CODE_8                                        False
# post_INST_CODE_9                                        False
# post_INST_CODE_10                                       False
# post_INST_CODE_11                                       False
# post_INST_CODE_12                                       False
# post_INST_CODE_13                                       False
# post_INST_CODE_14                                       False
# post_INST_CODE_15                                       False
# post_INST_CODE_16                                       False
# post_INST_CODE_17                                       False
# post_INST_CODE_18                                       False
# post_INST_CODE_19                                       False
# post_INST_CODE_20                                       False
# post_INST_CODE_21                                       False
# post_INST_CODE_22                                       False
# post_INST_CODE_23                                       False
# post_INST_CODE_24                                       False
# post_INST_CODE_25                                       False
# post_INST_CODE_26                                       False
# post_INST_CODE_27                                       False
# post_INST_CODE_28                                       False
# post_INST_CODE_29                                       False
# post_INST_CODE_30                                       False
# post_INST_CODE_31                                       False
# post_INST_CODE_32                                       False
# post_INST_CODE_33                                       False
# post_INST_CODE_34                                       False
# post_INST_CODE_35                                       False
# post_INST_CODE_36                                       False
# post_INST_CODE_37                                       False
# post_INST_CODE_38                                       False
# post_INST_CODE_39                                       False
# post_INST_CODE_40                                       False
# post_INST_CODE_41                                       False
# post_INST_CODE_42                                       False
# post_INST_CODE_43                                       False
# post_INST_CODE_44                                       False
# post_INST_CODE_45                                       False
# post_INST_CODE_46                                       False
# post_INST_CODE_47                                       False
# post_INST_CODE_48                                       False
# post_INST_CODE_49                                       False
# post_INST_CODE_50                                       False
# post_INST_CODE_51                                       False
# post_INST_CODE_52                                       False
# post_INST_CODE_53                                       False
# post_INST_CODE_54                                       False
# post_hosp_name_1                                        False
# post_hosp_name_2                                        False
# post_hosp_name_3                                        False
# post_hosp_name_4                                        False
# post_hosp_name_5                                        False
# post_hosp_name_6                                        False
# post_hosp_name_7                                        False
# post_hosp_name_8                                        False
# post_hosp_name_9                                        False
# post_hosp_name_10                                       False
# post_hosp_name_11                                       False
# post_hosp_name_12                                       False
# post_hosp_name_13                                       False
# post_hosp_name_14                                       False
# post_hosp_name_15                                       False
# post_hosp_name_16                                       False
# post_hosp_name_17                                       False
# post_hosp_name_18                                       False
# post_hosp_name_19                                       False
# post_hosp_name_20                                       False
# post_hosp_name_21                                       False
# post_hosp_name_22                                       False
# post_hosp_name_23                                       False
# post_hosp_name_24                                       False
# post_hosp_name_25                                       False
# post_hosp_name_26                                       False
# post_hosp_name_27                                       False
# post_hosp_name_28                                       False
# post_hosp_name_29                                       False
# post_hosp_name_30                                       False
# post_hosp_name_31                                       False
# post_hosp_name_32                                       False
# post_hosp_name_33                                       False
# post_hosp_name_34                                       False
# post_hosp_name_35                                       False
# post_hosp_name_36                                       False
# post_hosp_name_37                                       False
# post_hosp_name_38                                       False
# post_hosp_name_39                                       False
# post_hosp_name_40                                       False
# post_hosp_name_41                                       False
# post_hosp_name_42                                       False
# post_hosp_name_43                                       False
# post_hosp_name_44                                       False
# post_hosp_name_45                                       False
# post_hosp_name_46                                       False
# post_hosp_name_47                                       False
# post_hosp_name_48                                       False
# post_hosp_name_49                                       False
# post_hosp_name_50                                       False
# post_hosp_name_51                                       False
# post_hosp_name_52                                       False
# post_hosp_name_53                                       False
# post_hosp_name_54                                       False
# post_LOS_1                                              False
# post_LOS_2                                              False
# post_LOS_3                                              False
# post_LOS_4                                              False
# post_LOS_5                                              False
# post_LOS_6                                              False
# post_LOS_7                                              False
# post_LOS_8                                              False
# post_LOS_9                                              False
# post_LOS_10                                             False
# post_LOS_11                                             False
# post_LOS_12                                             False
# post_LOS_13                                             False
# post_LOS_14                                             False
# post_LOS_15                                             False
# post_LOS_16                                             False
# post_LOS_17                                             False
# post_LOS_18                                             False
# post_LOS_19                                             False
# post_LOS_20                                             False
# post_LOS_21                                             False
# post_LOS_22                                             False
# post_LOS_23                                             False
# post_LOS_24                                             False
# post_LOS_25                                             False
# post_LOS_26                                             False
# post_LOS_27                                             False
# post_LOS_28                                             False
# post_LOS_29                                             False
# post_LOS_30                                             False
# post_LOS_31                                             False
# post_LOS_32                                             False
# post_LOS_33                                             False
# post_LOS_34                                             False
# post_LOS_35                                             False
# post_LOS_36                                             False
# post_LOS_37                                             False
# post_LOS_38                                             False
# post_LOS_39                                             False
# post_LOS_40                                             False
# post_LOS_41                                             False
# post_LOS_42                                             False
# post_LOS_43                                             False
# post_LOS_44                                             False
# post_LOS_45                                             False
# post_LOS_46                                             False
# post_LOS_47                                             False
# post_LOS_48                                             False
# post_LOS_49                                             False
# post_LOS_50                                             False
# post_LOS_51                                             False
# post_LOS_52                                             False
# post_LOS_53                                             False
# post_LOS_54                                             False
# post_Death_date                                         False
# pre_internal_Ramipril Dose                              False
# pre_internal_Perindopril Dose                           False
# pre_internal_Lisinopril Dose                            False
# pre_internal_Enalapril Dose                             False
# pre_internal_Captopril Dose                             False
# pre_internal_Trandolapril Dose                          False
# pre_internal_Quinapril Dose                             False
# pre_internal_Benazepril Dose                            False
# pre_internal_Fosinopril Dose                            False
# pre_internal_Cilazapril Dose                            False
# pre_internal_Candesartan Dose                           False
# pre_internal_Valsartan Dose                             False
# pre_internal_Losartan Dose                              False
# pre_internal_Irbesartan Dose                            False
# pre_internal_Telmisartan Dose                           False
# pre_internal_Carvedilol Dose                            False
# pre_internal_Bisoprolol Dose                            False
# pre_internal_Metoprolol Dose                            False
# pre_internal_Nebivolol Dose                             False
# pre_internal_Atenolol Dose                              False
# pre_internal_Sotalol Dose                               False
# pre_internal_Propranalol Dose                           False
# pre_internal_Nadolol Dose                               False
# pre_internal_Acebutolol Dose                            False
# pre_internal_Labetolol Dose                             False
# pre_internal_Pindolol Dose                              False
# pre_internal_Timolol Dose                               False
# pre_internal_Spironolactone Dose                        False
# pre_internal_Eplerenone Dose                            False
# pre_internal_Furosemide Dose                            False
# pre_internal_Butenamide Dose                            False
# pre_internal_Torsemide Dose                             False
# dtype: bool

# %%
impute_info = pd.read_excel('VOCAL-HF UBC CIC Columns Missing Data 22.02.13.xlsx',engine='openpyxl')
cols_to_drop = []
# hx_columns = []
absent_columns = []
miss_zero_columns = []
miss_mean_columns=[]
miss_knn_columns=[]

#assign column names to a particular type of imputation
for i,row in impute_info.iterrows():
    method = row['Suggested Imputation Method']
    #this try-except is because the new columns names have prefixes as opposed to the ones that were labelled by Nat for the 
    #suggested imputation techniques 
    try:
        col = 'pre_internal_' + row['Column Name']
        assert col in df
        print(col,method)
    except:
        try:
            col = 'pre_CSBC_' + row['Column Name']
            assert col in df
            print(col,method)
        except:
            continue

    if method == 'Include' or method =='Missing = 0/None' or method == 'Missing = 0':
        miss_zero_columns.append(col)
    elif method == 'Exclude':
        if df[col].isnull().all():
            cols_to_drop.append(col)
        else:
            miss_mean_columns.append(col)
#         cols_to_drop.append(col)
    elif method == 'Missing = absent':
        absent_columns.append(col)
    elif method == 'Mean':
        miss_mean_columns.append(col)
    elif method == 'Impute':
        miss_knn_columns.append(col)
    else:
        print(col,method)
#         print('Other\n\n\n',col,method,'\n\n\n')





for col in miss_zero_columns:
    df[col] = df[col].fillna(0)
for col in absent_columns:
    if df[absent_columns].dtypes[col]==np.float64:
        print('float column', col)
        df[col] = df[col].fillna(0)
    else:
        print('object column', col)
        df[col] = df[col].fillna('Absent')
print(absent_columns)
df['pre_internal_LabAdm_INR']=df['pre_internal_LabAdm_INR'].fillna(1.0)
df['pre_internal_LabAdm_HbA1C']=df['pre_internal_LabAdm_HbA1C'].fillna(6.0)
df['pre_internal_LabDisch_INR']=df['pre_internal_LabDisch_INR'].fillna(1.0)
df['pre_internal_LabDisch_HbA1C']=df['pre_internal_LabDisch_HbA1C'].fillna(6.0)
df['pre_internal_ECG_Rhythm']=df['pre_internal_ECG_Rhythm'].fillna('Sinus rhythm')
df['pre_internal_ECG_QRS_Morphology']=df['pre_internal_ECG_QRS_Morphology'].fillna('Narrow')
df['pre_internal_ECG_AV_Block']=df['pre_internal_ECG_AV_Block'].fillna('No AV block')
df['pre_internal_Imaging_MR']=df['pre_internal_Imaging_MR'].fillna(0)
df['pre_internal_FollowUpAppointment']=df['pre_internal_FollowUpAppointment'].fillna(0)
# df['ExclusionReason']

bnp=[]
for i,row in df.iterrows():
    t1=row['pre_internal_LabAdm_BNP']
    t2=row['pre_internal_LabAdm_NT_proBNP']
    if not pd.isnull(t1):
        if t1[0]=='<' or t1[0]=='>':
#             print(x)
            t1=t1[1:]
        bnp.append(float(t1))
    elif not pd.isnull(t2):
        if t2[0]=='<' or t2[0]=='>':
#             print(x)
            t2=t2[1:]
        bnp.append(float(t2)/6.25)
    else:
        bnp.append(np.nan)
    print(t1,t2)
    
df['pre_internal_BNP']=bnp
miss_knn_columns.append('pre_internal_BNP')

tp=[]
for i,row in df.iterrows():
    t1=row['pre_internal_LabAdm_TroponinT']
    t2=row['pre_internal_LabAdm_TroponinI']
    if not pd.isnull(t1):
        if t1[0]=='<' or t1[0]=='>':
#             print(x)
            t1=t1[1:]
        tp.append(float(t1))
    elif not pd.isnull(t2):
        if t2[0]=='<' or t2[0]=='>':
#             print(x)
            t2=t2[1:]
        tp.append(float(t2)*1000)
    else:
        tp.append(np.nan)
#     print(t1,t2)
    
df['pre_internal_Troponin']=tp
miss_knn_columns.append('pre_internal_Troponin')

cols_to_drop.extend(['pre_internal_LabAdm_BNP','pre_internal_Death','pre_internal_LabAdm_NT_proBNP','pre_internal_LabAdm_TroponinI','pre_internal_LabAdm_TroponinT','pre_internal_DeathInHospital'])


df.drop(cols_to_drop,axis=1,inplace=True)

# df['ExclusionReason']
# Out:
# pre_internal_ELOS Mean
# pre_internal_ALOS_ELOS Mean
# pre_internal_Palliative Exclude
# pre_internal_hx_CKD Include
# pre_internal_hx_COPD Include
# pre_internal_hx_Asthma Include
# pre_internal_hx_Malignancy Include
# pre_internal_hx_LiverDisease Include
# pre_internal_hx_Anemia Include
# pre_internal_hx_PUD Include
# pre_internal_hx_Dementia Include
# pre_internal_hx_MI Include
# pre_internal_hx_Angina Include
# pre_internal_hx_CABG Include
# pre_internal_hx_PCI Include
# pre_internal_hx_CVA Include
# pre_internal_hx_TIA Include
# pre_internal_hx_PAD Include
# pre_internal_hx_DM Include
# pre_internal_hx_HTN Include
# pre_internal_hx_Smoking Include
# pre_internal_hx_AlcoholExcess Include
# pre_internal_hx_AF Include
# pre_internal_hx_AFL Include
# pre_internal_hx_VTE Include
# pre_internal_hx_ExistingHF Include
# pre_internal_hx_HF_Hospitalization Include
# pre_internal_hx_HeartTransplant Include
# pre_internal_Dyspnea Exclude
# pre_internal_Orthopnea Exclude
# pre_internal_PND Exclude
# pre_internal_Swelling Exclude
# pre_internal_Fatigue Exclude
# pre_internal_Syncope Exclude
# pre_internal_NYHA Exclude
# pre_internal_ChestPain Exclude
# pre_internal_Exam_Weight Mean
# pre_internal_Exam_HR Mean
# pre_internal_Exam_SBP Mean
# pre_internal_Exam_DBP Mean
# pre_internal_Exam_RespiratoryRate Mean
# pre_internal_Exam_OxygenSaturation Mean
# pre_internal_Exam_ReceivingOxygen Mean
# pre_internal_MedDisch_ACEI Missing = absent
# pre_internal_MedDisch_ACEI_NoReason Exclude
# pre_internal_MedDisch_ACEI_Name Exclude
# pre_internal_MedDisch_ACEI_Dose Missing = 0
# pre_internal_MedDisch_ACEI_Contraindication Missing = absent
# pre_internal_MedDisch_ARB Missing = absent
# pre_internal_MedDisch_ARB_NoReason Exclude
# pre_internal_MedDisch_ARB_Name Exclude
# pre_internal_MedDisch_ARB_Dose Missing = 0
# pre_internal_MedDisch_ARB_Contraindication Missing = absent
# pre_internal_MedDisch_BB Missing = absent
# pre_internal_MedDisch_BB_NoReason Exclude
# pre_internal_MedDisch_BB_Name Exclude
# pre_internal_MedDisch_BB_Dose Missing = 0
# pre_internal_MedDisch_BB_Contraindication Missing = absent
# pre_internal_MedDisch_MRA Missing = absent
# pre_internal_MedDisch_MRA_NoReason Exclude
# pre_internal_MedDisch_MRA_Name Exclude
# pre_internal_MedDisch_MRA_Dose Missing = 0
# pre_internal_MedDisch_MRA_Contraindication Missing = absent
# pre_internal_MedDisch_ARNI Missing = absent
# pre_internal_MedDisch_ARNI_NoReason Exclude
# pre_internal_MedDisch_ARNI_Contraindication Missing = absent
# pre_internal_MedDisch_ARNI_Dose Missing = 0
# pre_internal_MedDisch_DIG Missing = absent
# pre_internal_MedDisch_DIG_Dose Missing = 0
# pre_internal_MedDisch_Hydralazine Missing = absent
# pre_internal_MedDisch_NitrateOralOrPatch Missing = absent
# pre_internal_MedDisch_LoopDiuretic Missing = absent
# pre_internal_MedDisch_LoopDiureticName Exclude
# pre_internal_MedDisch_LoopDiureticDose Missing = 0
# pre_internal_MedDisch_ThiazideDiuretic Missing = absent
# pre_internal_MedDisch_ASA Missing = absent
# pre_internal_MedDisch_OtherAntiplatelet Missing = absent
# pre_internal_MedDisch_Heparin Exclude
# pre_internal_MedDisch_Warfarin Missing = absent
# pre_internal_MedDisch_WarfarinNoReason Exclude
# pre_internal_MedDisch_WarfarinContraindication Missing = absent
# pre_internal_MedDisch_NOAC Missing = absent
# pre_internal_MedDisch_NOAC_NoReason Exclude
# pre_internal_MedDisch_NOAC_Contraindication Missing = absent
# pre_internal_MedDisch_NOAC_Name Exclude
# pre_internal_MedDisch_NSAID Missing = absent
# pre_internal_MedDisch_Amiodarone Missing = absent
# pre_internal_MedDisch_CCB Missing = absent
# pre_internal_MedDisch_Statins Missing = absent
# pre_internal_Pacemaker Missing = absent
# pre_internal_PacemakerNoReason Exclude
# pre_internal_PacemakerType Exclude
# pre_internal_Defibrillator Missing = absent
# pre_internal_DefibrillatorNoReason Exclude
# pre_internal_DefibrillatorType Exclude
# pre_internal_Lab_BNP_UpperRefLimit Exclude
# pre_internal_Lab_NT_proBNP_UpperRefLimit Exclude
# pre_internal_Lab_TroponinI_UpperRefLimit Exclude
# pre_internal_Lab_TroponinT_UpperRefLimit Exclude
# pre_internal_Lab_EGFR_LowerRefLimit Exclude
# pre_internal_Lab_Ur_UpperRefLimit Exclude
# pre_internal_Lab_Ur_LowerRefLimit Exclude
# pre_internal_Lab_Hb_UpperRefLimit Exclude
# pre_internal_Lab_Hb_LowerRefLimit Exclude
# pre_internal_Lab_MCV_UpperRefLimit Exclude
# pre_internal_Lab_MCV_LowerRefLimit Exclude
# pre_internal_Lab_WBC_UpperRefLimit Exclude
# pre_internal_Lab_WBC_LowerRefLimit Exclude
# pre_internal_Lab_Platelets_UpperRefLimit Exclude
# pre_internal_Lab_Platelets_LowerRefLimit Exclude
# pre_internal_Lab_INR_UpperRefLimit Exclude
# pre_internal_Lab_INR_LowerRefLimit Exclude
# pre_internal_Lab_Iron_UpperRefLimit Exclude
# pre_internal_Lab_Iron_LowerRefLimit Exclude
# pre_internal_Lab_Ferritin_UpperRefLimit Exclude
# pre_internal_Lab_Ferritin_LowerRefLimit Exclude
# pre_internal_Lab_Bilirubin_UpperRefLimit Exclude
# pre_internal_Lab_AST_UpperRefLimit Exclude
# pre_internal_Lab_AST_LowerRefLimit Exclude
# pre_internal_Lab_ALT_UpperRefLimit Exclude
# pre_internal_Lab_ALT_LowerRefLimit Exclude
# pre_internal_Lab_ALP_UpperRefLimit Exclude
# pre_internal_Lab_ALP_LowerRefLimit Exclude
# pre_internal_Lab_GGT_UpperRefLimit Exclude
# pre_internal_Lab_GGT_LowerRefLimit Exclude
# pre_internal_Lab_Alb_UpperRefLimit Exclude
# pre_internal_Lab_Alb_LowerRefLimit Exclude
# pre_internal_Lab_TotalCholesterol_UpperRefLimit Exclude
# pre_internal_Lab_LDL_Cholesterol_UpperRefLimit Exclude
# pre_internal_Lab_UricAcid_UpperRefLimit Exclude
# pre_internal_Lab_UricAcid_LowerRefLimit Exclude
# pre_internal_LabAdm_BNP BNP and NT-proBNP should have been combined - need to discuss
# pre_internal_LabAdm_BNP BNP and NT-proBNP should have been combined - need to discuss
# pre_internal_LabAdm_BNP_Hours Exclude
# pre_internal_LabAdm_BNP_AbnormalityCode Exclude
# pre_internal_LabAdm_NT_proBNP BNP and NT-proBNP should have been combined - need to discuss
# pre_internal_LabAdm_NT_proBNP BNP and NT-proBNP should have been combined - need to discuss
# pre_internal_LabAdm_NT_proBNP_Hours Exclude
# pre_internal_LabAdm_NT_proBNP_AbnormalityCode Exclude
# pre_internal_LabAdm_TroponinI Can Troponin I and T be combined?
# pre_internal_LabAdm_TroponinI Can Troponin I and T be combined?
# pre_internal_LabAdm_TroponinI_Hours Exclude
# pre_internal_LabAdm_TroponinI_AbnormalityCode Exclude
# pre_internal_LabAdm_TroponinT Can Troponin I and T be combined?
# pre_internal_LabAdm_TroponinT Can Troponin I and T be combined?
# pre_internal_LabAdm_TroponinT_Hours Exclude
# pre_internal_LabAdm_TroponinT_AbnormalityCode Exclude
# pre_internal_LabAdm_Cr Mean
# pre_internal_LabAdm_Cr_Hours Mean
# pre_internal_LabAdm_Cr_AbnormalityCode Mean
# pre_internal_LabAdm_EGFR Mean
# pre_internal_LabAdm_EGFR_Hours Mean
# pre_internal_LabAdm_EGFR_AbnormalityCode Exclude
# pre_internal_LabAdm_Na Mean
# pre_internal_LabAdm_Na_Hours Mean
# pre_internal_LabAdm_Na_AbnormalityCode Mean
# pre_internal_LabAdm_K Mean
# pre_internal_LabAdm_K_Hours Mean
# pre_internal_LabAdm_K_AbnormalityCode Mean
# pre_internal_LabAdm_Ur Mean
# pre_internal_LabAdm_Ur_Hours Mean
# pre_internal_LabAdm_Ur_AbnormalityCode Exclude
# pre_internal_LabAdm_Hb Mean
# pre_internal_LabAdm_Hb_Hours Mean
# pre_internal_LabAdm_Hb_AbnormalityCode Exclude
# pre_internal_LabAdm_MCV Mean
# pre_internal_LabAdm_MCV_Hours Mean
# pre_internal_LabAdm_MCV_AbnormalityCode Exclude
# pre_internal_LabAdm_WBC Mean
# pre_internal_LabAdm_WBC_Hours Mean
# pre_internal_LabAdm_WBC_AbnormalityCode Exclude
# pre_internal_LabAdm_Platelets Mean
# pre_internal_LabAdm_Platelets_Hours Mean
# pre_internal_LabAdm_Platelets_AbnormalityCode Exclude
# pre_internal_LabAdm_INR Absent = 1.0
# pre_internal_LabAdm_INR Absent = 1.0
# pre_internal_LabAdm_INR_Hours Exclude
# pre_internal_LabAdm_INR_AbnormalityCode Exclude
# pre_internal_LabAdm_HbA1C Absent = 6.0
# pre_internal_LabAdm_HbA1C Absent = 6.0
# pre_internal_LabAdm_HbA1C_Hours Exclude
# pre_internal_LabAdm_HbA1C_AbnormalityCode Exclude
# pre_internal_LabAdm_Iron Impute
# pre_internal_LabAdm_Iron_Hours Exclude
# pre_internal_LabAdm_Iron_AbnormalityCode Exclude
# pre_internal_LabAdm_Ferritin Impute
# pre_internal_LabAdm_Ferritin_Hours Exclude
# pre_internal_LabAdm_Ferritin_AbnormalityCode Exclude
# pre_internal_LabAdm_Bilirubin Impute
# pre_internal_LabAdm_Bilirubin_Hours Exclude
# pre_internal_LabAdm_Bilirubin_AbnormalityCode Exclude
# pre_internal_LabAdm_AST Impute
# pre_internal_LabAdm_AST_Hours Exclude
# pre_internal_LabAdm_AST_AbnormalityCode Exclude
# pre_internal_LabAdm_ALT Impute
# pre_internal_LabAdm_ALT_Hours Exclude
# pre_internal_LabAdm_ALT_AbnormalityCode Exclude
# pre_internal_LabAdm_ALP Impute
# pre_internal_LabAdm_ALP_Hours Exclude
# pre_internal_LabAdm_ALP_AbnormalityCode Exclude
# pre_internal_LabAdm_GGT Impute
# pre_internal_LabAdm_GGT_Hours Exclude
# pre_internal_LabAdm_GGT_AbnormalityCode Exclude
# pre_internal_LabAdm_Alb Impute
# pre_internal_LabAdm_Alb_Hours Exclude
# pre_internal_LabAdm_Alb_AbnormalityCode Exclude
# pre_internal_LabAdm_TotalCholesterol Exclude
# pre_internal_LabAdm_TotalCholesterol_Hours Exclude
# pre_internal_LabAdm_TotalCholesterol_AbnormalityCode Exclude
# pre_internal_LabAdm_LDL_Cholesterol Exclude
# pre_internal_LabAdm_LDL_Cholesterol_Hours Exclude
# pre_internal_LabAdm_LDL_Cholesterol_AbnormalityCode Exclude
# pre_internal_LabAdm_UricAcid Exclude
# pre_internal_LabAdm_UricAcid_Hours Exclude
# pre_internal_LabAdm_UricAcid_AbnormalityCode Exclude
# pre_internal_LabDisch_Cr Mean
# pre_internal_LabDisch_Cr_Hours Mean
# pre_internal_LabDisch_Cr_AbnormalityCode Mean
# pre_internal_LabDisch_EGFR Mean
# pre_internal_LabDisch_EGFR_Hours Mean
# pre_internal_LabDisch_EGFR_AbnormalityCode Exclude
# pre_internal_LabDisch_Na Mean
# pre_internal_LabDisch_Na_Hours Mean
# pre_internal_LabDisch_Na_AbnormalityCode Mean
# pre_internal_LabDisch_K Mean
# pre_internal_LabDisch_K_Hours Mean
# pre_internal_LabDisch_K_AbnormalityCode Mean
# pre_internal_LabDisch_Ur Mean
# pre_internal_LabDisch_Ur_Hours Mean
# pre_internal_LabDisch_Ur_AbnormalityCode Exclude
# pre_internal_LabDisch_Hb Mean
# pre_internal_LabDisch_Hb_Hours Mean
# pre_internal_LabDisch_Hb_AbnormalityCode Exclude
# pre_internal_LabDisch_MCV Mean
# pre_internal_LabDisch_MCV_Hours Mean
# pre_internal_LabDisch_MCV_AbnormalityCode Exclude
# pre_internal_LabDisch_WBC Mean
# pre_internal_LabDisch_WBC_Hours Mean
# pre_internal_LabDisch_WBC_AbnormalityCode Exclude
# pre_internal_LabDisch_Platelets Mean
# pre_internal_LabDisch_Platelets_Hours Mean
# pre_internal_LabDisch_Platelets_AbnormalityCode Exclude
# pre_internal_LabDisch_INR Absent = 1.0
# pre_internal_LabDisch_INR Absent = 1.0
# pre_internal_LabDisch_INR_Hours Exclude
# pre_internal_LabDisch_INR_AbnormalityCode Exclude
# pre_internal_LabDisch_HbA1C Absent = 6.0
# pre_internal_LabDisch_HbA1C Absent = 6.0
# pre_internal_LabDisch_HbA1C_Hours Exclude
# pre_internal_LabDisch_HbA1C_AbnormalityCode Exclude
# pre_internal_LabDisch_Iron Exclude
# pre_internal_LabDisch_Iron_Hours Exclude
# pre_internal_LabDisch_Iron_AbnormalityCode Exclude
# pre_internal_LabDisch_Ferritin Exclude
# pre_internal_LabDisch_Ferritin_Hours Exclude
# pre_internal_LabDisch_Ferritin_AbnormalityCode Exclude
# pre_internal_LabDisch_Bilirubin Exclude
# pre_internal_LabDisch_Bilirubin_Hours Exclude
# pre_internal_LabDisch_Bilirubin_AbnormalityCode Exclude
# pre_internal_LabDisch_AST Exclude
# pre_internal_LabDisch_AST_Hours Exclude
# pre_internal_LabDisch_AST_AbnormalityCode Exclude
# pre_internal_LabDisch_ALT Exclude
# pre_internal_LabDisch_ALT_Hours Exclude
# pre_internal_LabDisch_ALT_AbnormalityCode Exclude
# pre_internal_LabDisch_ALP Exclude
# pre_internal_LabDisch_ALP_Hours Exclude
# pre_internal_LabDisch_ALP_AbnormalityCode Exclude
# pre_internal_LabDisch_GGT Exclude
# pre_internal_LabDisch_GGT_Hours Exclude
# pre_internal_LabDisch_GGT_AbnormalityCode Exclude
# pre_internal_LabDisch_Alb Exclude
# pre_internal_LabDisch_Alb_Hours Exclude
# pre_internal_LabDisch_Alb_AbnormalityCode Exclude
# pre_internal_LabDisch_UricAcid Exclude
# pre_internal_LabDisch_UricAcid_Hours Exclude
# pre_internal_LabDisch_UricAcid_AbnormalityCode Exclude
# pre_internal_ECG_HR Mean
# pre_internal_ECG_Rhythm Missing = sinus rhythm
# pre_internal_ECG_Rhythm Missing = sinus rhythm
# pre_internal_ECG_QRS_Duration Mean
# pre_internal_ECG_QRS_Morphology Missing = normal
# pre_internal_ECG_QRS_Morphology Missing = normal
# pre_internal_ECG_AV_Block Missing = normal
# pre_internal_ECG_AV_Block Missing = normal
# pre_internal_ECG_PR_Interval Exclude
# pre_internal_ECG_QT_Interval Mean
# pre_internal_Imaging_TechnicalDifficulty Exclude
# pre_internal_Imaging_EF_Modality Exclude
# pre_internal_Imaging_LVEF Impute
# pre_internal_Imaging_LVEF_Date Exclude
# pre_internal_Imaging_LVEF_Year Exclude
# pre_internal_Imaging_DiastolicDysfunction Exclude
# pre_internal_Imaging_MR Missing = none
# pre_internal_Imaging_MR Missing = none
# pre_internal_Imaging_AS Exclude
# pre_internal_Imaging_OtherValveDisease Exclude
# pre_internal_AdmissionUnitCode Exclude
# pre_internal_DischargeUnitCode Exclude
# pre_internal_InpatientOrderSet Missing = absent
# pre_internal_HeartFailureTeachingRecord Missing = absent
# pre_internal_DischargeGuidelinesForHeartFailure Missing = absent
# pre_internal_HeartFailureDischargeInstructions Missing = absent
# pre_internal_DischargeMedRec Exclude
# pre_internal_DischargeRxGiven Missing = absent
# pre_internal_FollowUpAppointment Missing = none
# pre_internal_FollowUpAppointment Missing = none
# pre_CSBC_pre_diag_date Exclude
# pre_CSBC_pre_diag_flag Exclude
# pre_CSBC_pre_PCI_date Exclude
# pre_CSBC_pre_pci_flag Missing = 0/None
# pre_CSBC_pre_CABG_date Exclude
# pre_CSBC_pre_cabg_flag Missing = 0/None
# pre_CSBC_pre_valve_date Exclude
# pre_CSBC_pre_valve_flag Missing = 0/None
# pre_CSBC_pre_ablation_date Exclude
# pre_CSBC_pre_ablation_flag Missing = 0/None
# pre_CSBC_pre_PM_date Exclude
# pre_CSBC_pre_PM_flag Missing = 0/None
# pre_CSBC_pre_ICD_date Exclude
# pre_CSBC_pre_ICD_flag Missing = 0/None
# pre_CSBC_pre_CRT_date Exclude
# pre_CSBC_pre_CRT_flag Missing = 0/None
# pre_internal_Bisoprolol Dose Exclude
# float column pre_internal_MedDisch_ACEI
# object column pre_internal_MedDisch_ACEI_Contraindication
# float column pre_internal_MedDisch_ARB
# object column pre_internal_MedDisch_ARB_Contraindication
# float column pre_internal_MedDisch_BB
# object column pre_internal_MedDisch_BB_Contraindication
# float column pre_internal_MedDisch_MRA
# object column pre_internal_MedDisch_MRA_Contraindication
# float column pre_internal_MedDisch_ARNI
# object column pre_internal_MedDisch_ARNI_Contraindication
# float column pre_internal_MedDisch_DIG
# float column pre_internal_MedDisch_Hydralazine
# float column pre_internal_MedDisch_NitrateOralOrPatch
# float column pre_internal_MedDisch_LoopDiuretic
# float column pre_internal_MedDisch_ThiazideDiuretic
# float column pre_internal_MedDisch_ASA
# float column pre_internal_MedDisch_OtherAntiplatelet
# float column pre_internal_MedDisch_Warfarin
# object column pre_internal_MedDisch_WarfarinContraindication
# float column pre_internal_MedDisch_NOAC
# object column pre_internal_MedDisch_NOAC_Contraindication
# float column pre_internal_MedDisch_NSAID
# float column pre_internal_MedDisch_Amiodarone
# float column pre_internal_MedDisch_CCB
# float column pre_internal_MedDisch_Statins
# float column pre_internal_Pacemaker
# float column pre_internal_Defibrillator
# float column pre_internal_InpatientOrderSet
# object column pre_internal_HeartFailureTeachingRecord
# object column pre_internal_DischargeGuidelinesForHeartFailure
# object column pre_internal_HeartFailureDischargeInstructions
# float column pre_internal_DischargeRxGiven
# ['pre_internal_MedDisch_ACEI', 'pre_internal_MedDisch_ACEI_Contraindication', 'pre_internal_MedDisch_ARB', 'pre_internal_MedDisch_ARB_Contraindication', 'pre_internal_MedDisch_BB', 'pre_internal_MedDisch_BB_Contraindication', 'pre_internal_MedDisch_MRA', 'pre_internal_MedDisch_MRA_Contraindication', 'pre_internal_MedDisch_ARNI', 'pre_internal_MedDisch_ARNI_Contraindication', 'pre_internal_MedDisch_DIG', 'pre_internal_MedDisch_Hydralazine', 'pre_internal_MedDisch_NitrateOralOrPatch', 'pre_internal_MedDisch_LoopDiuretic', 'pre_internal_MedDisch_ThiazideDiuretic', 'pre_internal_MedDisch_ASA', 'pre_internal_MedDisch_OtherAntiplatelet', 'pre_internal_MedDisch_Warfarin', 'pre_internal_MedDisch_WarfarinContraindication', 'pre_internal_MedDisch_NOAC', 'pre_internal_MedDisch_NOAC_Contraindication', 'pre_internal_MedDisch_NSAID', 'pre_internal_MedDisch_Amiodarone', 'pre_internal_MedDisch_CCB', 'pre_internal_MedDisch_Statins', 'pre_internal_Pacemaker', 'pre_internal_Defibrillator', 'pre_internal_InpatientOrderSet', 'pre_internal_HeartFailureTeachingRecord', 'pre_internal_DischargeGuidelinesForHeartFailure', 'pre_internal_HeartFailureDischargeInstructions', 'pre_internal_DischargeRxGiven']
# nan 32477
# 133 nan
# 2345 nan
# nan 1311
# nan nan
# nan 6633
# nan 504
# nan 7154
# 1929 nan
# nan 2378
# nan 23362
# nan 7369
# nan 10795
# nan 10095
# nan 4832
# nan nan
# nan 17950
# nan 9391
# nan 2829
# 2860 nan
# 609 nan
# nan 26388
# 512 nan
# 495 nan
# nan 23903
# nan 4666
# nan nan
# nan 176

# %%
#Add new features of day and month

import datetime


for hosp in range(1,55,1):
    adm_day=[]
    adm_month=[]
    discharge_day=[]
    discharge_month=[]
    for i,row in df.iterrows():
        date = row['post_ADMISSION_DATE_'+str(hosp)]
        if pd.isnull(date):
            adm_day.append(np.nan)
            adm_month.append(np.nan)
            discharge_day.append(np.nan)
            discharge_month.append(np.nan)
        else:
#         print(date)
            at=datetime.datetime.strptime(date,'%Y-%m-%d')
            adm_day.append(at.weekday())
            adm_month.append(at.month)

            dt=datetime.datetime.strptime(date,'%Y-%m-%d') + datetime.timedelta(days=row['post_LOS_'+str(hosp)])
            discharge_day.append(dt.weekday())
            discharge_month.append(dt.month)
    df['post_ADMISSION_DATE_DAY_'+str(hosp)]=adm_day
    df['post_ADMISSION_DATE_MONTH_'+str(hosp)]=adm_month

    df['post_Discharge_Day_'+str(hosp)]=discharge_day
    df['post_Discharge_Month_'+str(hosp)]=discharge_month

# %%
df['post_n_rehosp']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
# 20       NaN
# 21       NaN
# 22       NaN
# 23       NaN
# 24       NaN
# 25       NaN
# 26       NaN
# 27       NaN
# 28       NaN
# 29       NaN
# 30       NaN
# 31       NaN
# 32       NaN
# 33       NaN
# 34      10.0
# 35       3.0
# 36       2.0
# 37       9.0
# 38      15.0
# 39       1.0
# 40       6.0
# 41       1.0
# 42       1.0
# 43       NaN
# 44       1.0
# 45       2.0
# 46       NaN
# 47       2.0
# 48       3.0
# 49       1.0
# 50       2.0
# 51      54.0
# 52       1.0
# 53       NaN
# 54       3.0
# 55       NaN
# 56       NaN
# 57       2.0
# 58       1.0
# 59       NaN
# 60       2.0
# 61      12.0
# 62       NaN
# 63       2.0
# 64       NaN
# 65      12.0
# 66       5.0
# 67       NaN
# 68       3.0
# 69       2.0
# 70       NaN
# 71       NaN
# 72       1.0
# 73       2.0
# 74       1.0
# 75       2.0
# 76       8.0
# 77       1.0
# 78       NaN
# 79       4.0
# 80       1.0
# 81       4.0
# 82       3.0
# 83       4.0
# 84       NaN
# 85       NaN
# 86       2.0
# 87       NaN
# 88       NaN
# 89       2.0
# 90       NaN
# 91       1.0
# 92       1.0
# 93       2.0
# 94       2.0
# 95       3.0
# 96       1.0
# 97       1.0
# 98       NaN
# 99       1.0
# 100      NaN
# 101      1.0
# 102      3.0
# 103      1.0
# 104      2.0
# 105      NaN
# 106      5.0
# 107      NaN
# 108      2.0
# 109      6.0
# 110      5.0
# 111      2.0
# 112      NaN
# 113      NaN
# 114     12.0
# 115      1.0
# 116      1.0
# 117      3.0
# 118      4.0
# 119      1.0
# 120      4.0
# 121      2.0
# 122      NaN
# 123      2.0
# 124      3.0
# 125      2.0
# 126      NaN
# 127      2.0
# 128      1.0
# 129      4.0
# 130      5.0
# 131      2.0
# 132      1.0
# 133      NaN
# 134      1.0
# 135      1.0
# 136      2.0
# 137     19.0
# 138      3.0
# 139      NaN
# 140      2.0
# 141      1.0
# 142      6.0
# 143      2.0
# 144      3.0
# 145      NaN
# 146      3.0
# 147      NaN
# 148      NaN
# 149      2.0
# 150      8.0
# 151      7.0
# 152      1.0
# 153      NaN
# 154      NaN
# 155      1.0
# 156      NaN
# 157      6.0
# 158      5.0
# 159      NaN
# 160      NaN
# 161      1.0
# 162      3.0
# 163      1.0
# 164      1.0
# 165      6.0
# 166      7.0
# 167      1.0
# 168      1.0
# 169      NaN
# 170      2.0
# 171      4.0
# 172      NaN
# 173      NaN
# 174      NaN
# 175      NaN
# 176      4.0
# 177      1.0
# 178      1.0
# 179      1.0
# 180      1.0
# 181      NaN
# 182      1.0
# 183      1.0
# 184      1.0
# 185      6.0
# 186      6.0
# 187      3.0
# 188      3.0
# 189      2.0
# 190      5.0
# 191      NaN
# 192      1.0
# 193      NaN
# 194      1.0
# 195      1.0
# 196      8.0
# 197      4.0
# 198      5.0
# 199      6.0
# 200      NaN
# 201      NaN
# 202      1.0
# 203      NaN
# 204      4.0
# 205      NaN
# 206      4.0
# 207      1.0
# 208      3.0
# 209      NaN
# 210      3.0
# 211      4.0
# 212      NaN
# 213      5.0
# 214      3.0
# 215      4.0
# 216      NaN
# 217      NaN
# 218      NaN
# 219      3.0
# 220      NaN
# 221      NaN
# 222      1.0
# 223      1.0
# 224      2.0
# 225      NaN
# 226      1.0
# 227      NaN
# 228      2.0
# 229      2.0
# 230      NaN
# 231      1.0
# 232      1.0
# 233      NaN
# 234      NaN
# 235      NaN
# 236      1.0
# 237      2.0
# 238      7.0
# 239      1.0
# 240      2.0
# 241      1.0
# 242     21.0
# 243      5.0
# 244      NaN
# 245      NaN
# 246      3.0
# 247      4.0
# 248      NaN
# 249      1.0
# 250      1.0
# 251      NaN
# 252      NaN
# 253      NaN
# 254      NaN
# 255      2.0
# 256      2.0
# 257      1.0
# 258      NaN
# 259      NaN
# 260      1.0
# 261      NaN
# 262      NaN
# 263      NaN
# 264      2.0
# 265      3.0
# 266      NaN
# 267      NaN
# 268      2.0
# 269      1.0
# 270      2.0
# 271      NaN
# 272      NaN
# 273      2.0
# 274      5.0
# 275      3.0
# 276      2.0
# 277      5.0
# 278      1.0
# 279      NaN
# 280      NaN
# 281      NaN
# 282      5.0
# 283      NaN
# 284     31.0
# 285      2.0
# 286      NaN
# 287      3.0
# 288      4.0
# 289      8.0
# 290      1.0
# 291      2.0
# 292      NaN
# 293      1.0
# 294      4.0
# 295      3.0
# 296      6.0
# 297      3.0
# 298      NaN
# 299      NaN
# 300      3.0
# 301      4.0
# 302      5.0
# 303      1.0
# 304      2.0
# 305      NaN
# 306      NaN
# 307      9.0
# 308      NaN
# 309      NaN
# 310      NaN
# 311      NaN
# 312      NaN
# 313      NaN
# 314      NaN
# 315      NaN
# 316      1.0
# 317      NaN
# 318      2.0
# 319      4.0
# 320     17.0
# 321      1.0
# 322      3.0
# 323      6.0
# 324      1.0
# 325      3.0
# 326      1.0
# 327      2.0
# 328      3.0
# 329      5.0
# 330      NaN
# 331      1.0
# 332      NaN
# 333      6.0
# 334      NaN
# 335      4.0
# 336      1.0
# 337      NaN
# 531      3.0
# 532      2.0
# 533      8.0
# 534     12.0
# 535      5.0
# 536      NaN
# 537      2.0
# 538      2.0
# 539      1.0
# 540     10.0
# 541      4.0
# 542      2.0
# 543      NaN
# 544      NaN
# 545      NaN
# 546      1.0
# 547      1.0
# 548      1.0
# 549      2.0
# 550     20.0
# 551      1.0
# 552      9.0
# 553      7.0
# 554      2.0
# 555      2.0
# 556      3.0
# 557      NaN
# 558      2.0
# 559      3.0
# 560      2.0
# 561      2.0
# 562      4.0
# 563      NaN
# 564      5.0
# 565      NaN
# 566      NaN
# 567      3.0
# 568      2.0
# 569      NaN
# 570      2.0
# 571      2.0
# 572      6.0
# 573      3.0
# 574      2.0
# 575      1.0
# 576      3.0
# 577      NaN
# 578      NaN
# 579      1.0
# 580      1.0
# 581      4.0
# 582      1.0
# 583      3.0
# 584      9.0
# 585      1.0
# 586      1.0
# 587      NaN
# 588      5.0
# 589      1.0
# 590      5.0
# 591      NaN
# 592      NaN
# 593      1.0
# 594      NaN
# 595      3.0
# 596      NaN
# 597      NaN
# 598      2.0
# 599      2.0
# 600      NaN
# 601      6.0
# 602      NaN
# 603      3.0
# 604      NaN
# 605      2.0
# 606      1.0
# 607      2.0
# 608      4.0
# 609      1.0
# 610      4.0
# 611      1.0
# 612      3.0
# 613      NaN
# 614      3.0
# 615      NaN
# 616      NaN
# 617      NaN
# 618      NaN
# 619      NaN
# 620      2.0
# 621      1.0
# 622      1.0
# 623      3.0
# 624      3.0
# 625      3.0
# 626      2.0
# 627      1.0
# 628      NaN
# 629      1.0
# 630      2.0
# 631      NaN
# 632      2.0
# 633      NaN
# 634      8.0
# 635      NaN
# 636      1.0
# 637      2.0
# 638      NaN
# 639      6.0
# 640      2.0
# 641      NaN
# 642      1.0
# 643      2.0
# 644      5.0
# 645      NaN
# 646      1.0
# 647      3.0
# 648      4.0
# 649      3.0
# 650      1.0
# 651      1.0
# 652      3.0
# 653      2.0
# 654      1.0
# 655      1.0
# 656      2.0
# 657      NaN
# 658      1.0
# 659      7.0
# 660      NaN
# 661      NaN
# 662      NaN
# 663      NaN
# 664      NaN
# 665      1.0
# 666      NaN
# 667      2.0
# 668      1.0
# 669      2.0
# 670      NaN
# 671      1.0
# 672      1.0
# 673      2.0
# 674      2.0
# 675      5.0
# 676      1.0
# 677      NaN
# 678      5.0
# 679      2.0
# 680      3.0
# 681      1.0
# 682      1.0
# 683      3.0
# 684      1.0
# 685      2.0
# 686      1.0
# 687      2.0
# 688      NaN
# 689      NaN
# 690      2.0
# 691      3.0
# 692      3.0
# 693      1.0
# 694      1.0
# 695      2.0
# 696      NaN
# 697      1.0
# 698      2.0
# 699      3.0
# 700      5.0
# 701      1.0
# 702      1.0
# 703      7.0
# 704      NaN
# 705      1.0
# 706      3.0
# 707      2.0
# 708      NaN
# 709      4.0
# 710      NaN
# 711      NaN
# 712      2.0
# 713      1.0
# 714      NaN
# 715      NaN
# 716      1.0
# 717      1.0
# 718     10.0
# 719      2.0
# 720      NaN
# 721      NaN
# 722      3.0
# 1781     NaN
# 1782     5.0
# 1783     5.0
# 1784     1.0
# 1785     NaN
# 1786     1.0
# 1787     2.0
# 1788     NaN
# 1789     2.0
# 1790     NaN
# 1791     NaN
# 1792     1.0
# 1793     NaN
# 1794     3.0
# 1795     3.0
# 1796     NaN
# 1797     NaN
# 1798     1.0
# 1799     6.0
# 1800     NaN
# 1801     NaN
# 1802     5.0
# 1803     NaN
# 1804     1.0
# 1805     NaN
# 1806     3.0
# 1807     3.0
# 1808     1.0
# 1809     2.0
# 1810     3.0
# 1811    29.0
# 1812     3.0
# 1813     3.0
# 1814     3.0
# 1815     1.0
# 1816    14.0
# 1817     1.0
# 1818     4.0
# 1819     5.0
# 1820     4.0
# 1821     6.0
# 1822     NaN
# 1823     3.0
# 1824     3.0
# 1825     8.0
# 1826     NaN
# 1827     2.0
# 1828     6.0
# 1829     NaN
# 1830     2.0
# 1831     4.0
# 1832     NaN
# 1833     6.0
# 1834     NaN
# 1835     3.0
# 1836     2.0
# 1837     NaN
# 1838     6.0
# 1839     3.0
# 1840    13.0
# 1841     1.0
# 1842     1.0
# 1843     NaN
# Name: post_n_rehosp, dtype: float64

# %%
#Create variable of death within N days

# print(list(df.columns))
t_death = []
for i,row in df.iterrows():
    if not pd.isna(row['post_Death_date']):
        hosp = int(row['post_n_rehosp'])
        disch_date = row['pre_internal_DischargeDate']
#         print(hosp)
        #dt=datetime.datetime.strptime(disch_date,'%m/%d/%Y %H:%M')
        dt=datetime.datetime.strptime(disch_date,'%Y-%m-%d')
        t = datetime.datetime.strptime(row['post_Death_date'],'%m/%d/%Y') - dt
        t=t.days
    else:
        t = np.inf
    t_death.append(t)
df['post_Time_to_death']=t_death
# for d in days_to_check:
#     df['Death_'+d]=df[]
# print(df['Time_to_death'])



for d in days_to_check:
    df[('post_Death_'+str(d))]=(df['post_Time_to_death']<=d).astype(int)

# print(df['Death_30'])

# %% [markdown]
# ## Look at class distributions

# %%
def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
#             print(rect)
#             print(rect.get_x() + rect.get_width() / 2, height)
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom',fontsize=20)

p1=[]

total_data=len(df)

for d in days_to_check:
    p1.append(np.round((df[('post_Death_'+str(d))].sum()/total_data)*100,2))

p1c=np.round([100.00-x for x in p1],2)

    

plt.rcParams["figure.figsize"] = (18,7)
fig, ax = plt.subplots()
x = np.arange(1,len(days_to_check)+1,1)  # the label locations
width=0.4
bar_width=0.4
rects1 = ax.bar(x-width, p1, bar_width, label='Dead',color='#F1A879',hatch='/')
rects2 = ax.bar(x , p1c, bar_width, label='Alive',color='#F4D4D4',hatch='*')

autolabel(rects1)
autolabel(rects2)

ax.legend(fontsize=30,loc='upper right')

ax.set_ylim([0,120])
plt.yticks(fontsize=30)
plt.xticks(ticks=x,labels = [x for x in days_to_check],fontsize=30)
# plt.set_xlabel([x/30 for x in days_to_check])
fig.tight_layout()
ax.set_ylabel('Percentage of total patients',fontsize=36)
ax.set_xlabel('Number of Days since Discharge',fontsize=36)
plt.title('Percentage of Patient Deaths over time',fontsize=36)
plt.grid(which='both',axis='y',color='gray', linestyle='--', linewidth=.5)
plt.minorticks_on()
plt.show()

# %% [markdown]
# # Begin Training Models

# %%
#Reorganizes dataframe

# %pip install imbalanced-learn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import StratifiedKFold
from sklearn.base import clone
from sklearn.model_selection import GridSearchCV
from sklearn import tree
from sklearn.tree import export_graphviz

from copy import deepcopy

print(df.shape)
cat_columns = list(df.select_dtypes(include=['object']).columns)#select those columns which are of 'object' type
df_factorized=deepcopy(df)
df_factorized[cat_columns] = df_factorized[cat_columns].apply(lambda x: pd.factorize(x)[0])
# df_not_missing = df_not_missing.drop(['CreateDate','AdmissionDate','DischargeDate','PatientAnonId','Unnamed: 0'],axis=1)
print(df.shape)

#drop 'unnamed' columns that happen due to pandas merging
df_factorized.drop(df.filter(regex="Unname"),axis=1, inplace=True)
#drop RefLimit columns as there is not enough data for them
df_factorized.drop(df.filter(regex="RefLimit"),axis=1, inplace=True)
print(df_factorized.dtypes)

#drop some columns to be imputed since we dropped them
miss_duplicate_mean_columns=[c for c in miss_mean_columns if c in list(df_factorized.columns)]
miss_mean_columns=miss_duplicate_mean_columns

# print(df_factorized.dtypes)
# print(df_factorized['MedDisch_NSAID'])
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.9.1-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 5.9 MB/s
# Requirement already satisfied: joblib>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from imbalanced-learn) (1.0.1)
# Requirement already satisfied: numpy>=1.17.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from imbalanced-learn) (1.19.5)
#   Downloading imbalanced_learn-0.9.0-py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 54.5 MB/s
#   Downloading imbalanced_learn-0.8.1-py3-none-any.whl (189 kB)
#      |████████████████████████████████| 189 kB 71.6 MB/s
# Requirement already satisfied: scikit-learn>=0.24 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from imbalanced-learn) (0.24.1)
# Requirement already satisfied: scipy>=0.19.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-learn>=0.24->imbalanced-learn) (2.1.0)
# Installing collected packages: imbalanced-learn
# Successfully installed imbalanced-learn-0.8.1
# Note: you may need to restart the kernel to use updated packages.
# (1844, 896)
# (1844, 896)
# pre_internal_VisitAnonId                                  int64
# pre_internal_PatientAnonId                                int64
# pre_internal_MrCareProviderAnonId                         int64
# pre_internal_MrCareProviderService                        int64
# pre_internal_Gender                                       int64
# pre_internal_Age                                          int64
# pre_internal_HealthAuthorityCode                          int64
# pre_internal_FacilityCode                                 int64
# pre_internal_AdmissionDate                                int64
# pre_internal_DischargeDate                                int64
# pre_internal_MRDx                                         int64
# pre_internal_MR_Unit                                      int64
# pre_internal_FiscalPeriod                                 int64
# pre_internal_FiscalYear                                   int64
# pre_internal_LOS                                          int64
# pre_internal_ALOS                                         int64
# pre_internal_ELOS                                       float64
# pre_internal_ALOS_ELOS                                  float64
# pre_internal_DischargeDisposition                         int64
# pre_internal_Palliative                                 float64
# pre_internal_AuditStatus                                  int64
# pre_internal_hx_CKD                                     float64
# pre_internal_hx_COPD                                    float64
# pre_internal_hx_Asthma                                  float64
# pre_internal_hx_Malignancy                              float64
# pre_internal_hx_LiverDisease                            float64
# pre_internal_hx_Anemia                                  float64
# pre_internal_hx_PUD                                     float64
# pre_internal_hx_Dementia                                float64
# pre_internal_hx_MI                                      float64
# pre_internal_hx_Angina                                  float64
# pre_internal_hx_CABG                                    float64
# pre_internal_hx_PCI                                     float64
# pre_internal_hx_CVA                                     float64
# pre_internal_hx_TIA                                     float64
# pre_internal_hx_PAD                                     float64
# pre_internal_hx_DM                                      float64
# pre_internal_hx_HTN                                     float64
# pre_internal_hx_Smoking                                   int64
# pre_internal_hx_AlcoholExcess                           float64
# pre_internal_hx_AF                                      float64
# pre_internal_hx_AFL                                     float64
# pre_internal_hx_VTE                                     float64
# pre_internal_hx_ExistingHF                              float64
# pre_internal_hx_HF_Hospitalization                      float64
# pre_internal_hx_HeartTransplant                         float64
# pre_internal_Dyspnea                                      int64
# pre_internal_Orthopnea                                  float64
# pre_internal_PND                                        float64
# pre_internal_Swelling                                   float64
# pre_internal_Fatigue                                    float64
# pre_internal_Syncope                                    float64
# pre_internal_NYHA                                         int64
# pre_internal_ChestPain                                  float64
# pre_internal_Exam_Weight                                float64
# pre_internal_Exam_WeightNotRecorded                       int64
# pre_internal_Exam_HR                                    float64
# pre_internal_Exam_SBP                                   float64
# pre_internal_Exam_DBP                                   float64
# pre_internal_Exam_RespiratoryRate                       float64
# pre_internal_Exam_OxygenSaturation                      float64
# pre_internal_Exam_ReceivingOxygen                       float64
# pre_internal_MedDisch_ACEI                              float64
# pre_internal_MedDisch_ACEI_NoReason                       int64
# pre_internal_MedDisch_ACEI_Name                           int64
# pre_internal_MedDisch_ACEI_Dose                         float64
# pre_internal_MedDisch_ACEI_Contraindication               int64
# pre_internal_MedDisch_ARB                               float64
# pre_internal_MedDisch_ARB_NoReason                        int64
# pre_internal_MedDisch_ARB_Name                            int64
# pre_internal_MedDisch_ARB_Dose                          float64
# pre_internal_MedDisch_ARB_Contraindication                int64
# pre_internal_MedDisch_BB                                float64
# pre_internal_MedDisch_BB_NoReason                         int64
# pre_internal_MedDisch_BB_Name                             int64
# pre_internal_MedDisch_BB_Dose                           float64
# pre_internal_MedDisch_BB_Contraindication                 int64
# pre_internal_MedDisch_MRA                               float64
# pre_internal_MedDisch_MRA_NoReason                        int64
# pre_internal_MedDisch_MRA_Name                            int64
# pre_internal_MedDisch_MRA_Dose                          float64
# pre_internal_MedDisch_MRA_Contraindication                int64
# pre_internal_MedDisch_ARNI                              float64
# pre_internal_MedDisch_ARNI_NoReason                       int64
# pre_internal_MedDisch_ARNI_Contraindication               int64
# pre_internal_MedDisch_ARNI_Dose                         float64
# pre_internal_MedDisch_DIG                               float64
# pre_internal_MedDisch_DIG_Dose                          float64
# pre_internal_MedDisch_Hydralazine                       float64
# pre_internal_MedDisch_NitrateOralOrPatch                float64
# pre_internal_MedDisch_LoopDiuretic                      float64
# pre_internal_MedDisch_LoopDiureticName                    int64
# pre_internal_MedDisch_LoopDiureticDose                  float64
# pre_internal_MedDisch_ThiazideDiuretic                  float64
# pre_internal_MedDisch_ASA                               float64
# pre_internal_MedDisch_OtherAntiplatelet                 float64
# pre_internal_MedDisch_Heparin                           float64
# pre_internal_MedDisch_Warfarin                          float64
# pre_internal_MedDisch_WarfarinNoReason                    int64
# pre_internal_MedDisch_WarfarinContraindication            int64
# pre_internal_MedDisch_NOAC                              float64
# pre_internal_MedDisch_NOAC_NoReason                       int64
# pre_internal_MedDisch_NOAC_Contraindication               int64
# pre_internal_MedDisch_NOAC_Name                           int64
# pre_internal_MedDisch_NSAID                             float64
# pre_internal_MedDisch_Amiodarone                        float64
# pre_internal_MedDisch_CCB                               float64
# pre_internal_MedDisch_Statins                           float64
# pre_internal_Pacemaker                                  float64
# pre_internal_PacemakerNoReason                            int64
# pre_internal_PacemakerType                                int64
# pre_internal_Defibrillator                              float64
# pre_internal_DefibrillatorNoReason                        int64
# pre_internal_DefibrillatorType                            int64
# pre_internal_Lab_BNP_Count                                int64
# pre_internal_Lab_NT_proBNP_Count                          int64
# pre_internal_Lab_TroponinI_Count                          int64
# pre_internal_Lab_TroponinT_Count                          int64
# pre_internal_Lab_Cr_Count                                 int64
# pre_internal_Lab_EGFR_Count                               int64
# pre_internal_Lab_Ur_Count                                 int64
# pre_internal_Lab_Na_Count                                 int64
# pre_internal_Lab_K_Count                                  int64
# pre_internal_Lab_Hb_Count                                 int64
# pre_internal_Lab_MCV_Count                                int64
# pre_internal_Lab_WBC_Count                                int64
# pre_internal_Lab_Platelets_Count                          int64
# pre_internal_Lab_INR_Count                                int64
# pre_internal_Lab_HbA1C_Count                              int64
# pre_internal_Lab_Iron_Count                               int64
# pre_internal_Lab_Ferritin_Count                           int64
# pre_internal_Lab_Bilirubin_Count                          int64
# pre_internal_Lab_AST_Count                                int64
# pre_internal_Lab_ALT_Count                                int64
# pre_internal_Lab_ALP_Count                                int64
# pre_internal_Lab_GGT_Count                                int64
# pre_internal_Lab_Alb_Count                                int64
# pre_internal_Lab_TotalCholesterol_Count                   int64
# pre_internal_Lab_LDL_Cholesterol_Count                    int64
# pre_internal_Lab_UricAcid_Count                           int64
# pre_internal_LabAdm_BNP_Hours                           float64
# pre_internal_LabAdm_BNP_AbnormalityCode                   int64
# pre_internal_LabAdm_NT_proBNP_Hours                     float64
# pre_internal_LabAdm_NT_proBNP_AbnormalityCode             int64
# pre_internal_LabAdm_TroponinI_Hours                     float64
# pre_internal_LabAdm_TroponinI_AbnormalityCode             int64
# pre_internal_LabAdm_TroponinT_Hours                     float64
# pre_internal_LabAdm_TroponinT_AbnormalityCode             int64
# pre_internal_LabAdm_Cr                                  float64
# pre_internal_LabAdm_Cr_Hours                            float64
# pre_internal_LabAdm_Cr_AbnormalityCode                    int64
# pre_internal_LabAdm_EGFR                                  int64
# pre_internal_LabAdm_EGFR_Hours                          float64
# pre_internal_LabAdm_EGFR_AbnormalityCode                  int64
# pre_internal_LabAdm_Ur                                  float64
# pre_internal_LabAdm_Ur_Hours                            float64
# pre_internal_LabAdm_Ur_AbnormalityCode                    int64
# pre_internal_LabAdm_Na                                  float64
# pre_internal_LabAdm_Na_Hours                            float64
# pre_internal_LabAdm_Na_AbnormalityCode                    int64
# pre_internal_LabAdm_K                                   float64
# pre_internal_LabAdm_K_Hours                             float64
# pre_internal_LabAdm_K_AbnormalityCode                     int64
# pre_internal_LabAdm_Hb                                  float64
# pre_internal_LabAdm_Hb_Hours                            float64
# pre_internal_LabAdm_Hb_AbnormalityCode                    int64
# pre_internal_LabAdm_MCV                                 float64
# pre_internal_LabAdm_MCV_Hours                           float64
# pre_internal_LabAdm_MCV_AbnormalityCode                   int64
# pre_internal_LabAdm_WBC                                 float64
# pre_internal_LabAdm_WBC_Hours                           float64
# pre_internal_LabAdm_WBC_AbnormalityCode                   int64
# pre_internal_LabAdm_Platelets                           float64
# pre_internal_LabAdm_Platelets_Hours                     float64
# pre_internal_LabAdm_Platelets_AbnormalityCode             int64
# pre_internal_LabAdm_INR                                   int64
# pre_internal_LabAdm_INR_Hours                           float64
# pre_internal_LabAdm_INR_AbnormalityCode                   int64
# pre_internal_LabAdm_HbA1C                               float64
# pre_internal_LabAdm_HbA1C_Hours                         float64
# pre_internal_LabAdm_HbA1C_AbnormalityCode                 int64
# pre_internal_LabAdm_Iron                                float64
# pre_internal_LabAdm_Iron_Hours                          float64
# pre_internal_LabAdm_Iron_AbnormalityCode                  int64
# pre_internal_LabAdm_Ferritin                            float64
# pre_internal_LabAdm_Ferritin_Hours                      float64
# pre_internal_LabAdm_Ferritin_AbnormalityCode              int64
# pre_internal_LabAdm_Bilirubin                             int64
# pre_internal_LabAdm_Bilirubin_Hours                     float64
# pre_internal_LabAdm_Bilirubin_AbnormalityCode             int64
# pre_internal_LabAdm_AST                                 float64
# pre_internal_LabAdm_AST_Hours                           float64
# pre_internal_LabAdm_AST_AbnormalityCode                   int64
# pre_internal_LabAdm_ALT                                   int64
# pre_internal_LabAdm_ALT_Hours                           float64
# pre_internal_LabAdm_ALT_AbnormalityCode                   int64
# pre_internal_LabAdm_ALP                                 float64
# pre_internal_LabAdm_ALP_Hours                           float64
# pre_internal_LabAdm_ALP_AbnormalityCode                   int64
# pre_internal_LabAdm_GGT                                 float64
# pre_internal_LabAdm_GGT_Hours                           float64
# pre_internal_LabAdm_GGT_AbnormalityCode                   int64
# pre_internal_LabAdm_Alb                                 float64
# pre_internal_LabAdm_Alb_Hours                           float64
# pre_internal_LabAdm_Alb_AbnormalityCode                   int64
# pre_internal_LabAdm_TotalCholesterol                    float64
# pre_internal_LabAdm_TotalCholesterol_Hours              float64
# pre_internal_LabAdm_TotalCholesterol_AbnormalityCode      int64
# pre_internal_LabAdm_LDL_Cholesterol                     float64
# pre_internal_LabAdm_LDL_Cholesterol_Hours               float64
# pre_internal_LabAdm_LDL_Cholesterol_AbnormalityCode       int64
# pre_internal_LabAdm_UricAcid                            float64
# pre_internal_LabAdm_UricAcid_Hours                      float64
# pre_internal_LabAdm_UricAcid_AbnormalityCode              int64
# pre_internal_LabDisch_Cr                                float64
# pre_internal_LabDisch_Cr_Hours                          float64
# pre_internal_LabDisch_Cr_AbnormalityCode                  int64
# pre_internal_LabDisch_EGFR                                int64
# pre_internal_LabDisch_EGFR_Hours                        float64
# pre_internal_LabDisch_EGFR_AbnormalityCode                int64
# pre_internal_LabDisch_Ur                                float64
# pre_internal_LabDisch_Ur_Hours                          float64
# pre_internal_LabDisch_Ur_AbnormalityCode                  int64
# pre_internal_LabDisch_Na                                float64
# pre_internal_LabDisch_Na_Hours                          float64
# pre_internal_LabDisch_Na_AbnormalityCode                  int64
# pre_internal_LabDisch_K                                 float64
# pre_internal_LabDisch_K_Hours                           float64
# pre_internal_LabDisch_K_AbnormalityCode                   int64
# pre_internal_LabDisch_Hb                                float64
# pre_internal_LabDisch_Hb_Hours                          float64
# pre_internal_LabDisch_Hb_AbnormalityCode                  int64
# pre_internal_LabDisch_MCV                               float64
# pre_internal_LabDisch_MCV_Hours                         float64
# pre_internal_LabDisch_MCV_AbnormalityCode                 int64
# pre_internal_LabDisch_WBC                               float64
# pre_internal_LabDisch_WBC_Hours                         float64
# pre_internal_LabDisch_WBC_AbnormalityCode                 int64
# pre_internal_LabDisch_Platelets                         float64
# pre_internal_LabDisch_Platelets_Hours                   float64
# pre_internal_LabDisch_Platelets_AbnormalityCode           int64
# pre_internal_LabDisch_INR                               float64
# pre_internal_LabDisch_INR_Hours                         float64
# pre_internal_LabDisch_INR_AbnormalityCode                 int64
# pre_internal_LabDisch_HbA1C                             float64
# pre_internal_LabDisch_HbA1C_Hours                       float64
# pre_internal_LabDisch_HbA1C_AbnormalityCode               int64
# pre_internal_LabDisch_Iron                              float64
# pre_internal_LabDisch_Iron_Hours                        float64
# pre_internal_LabDisch_Iron_AbnormalityCode                int64
# pre_internal_LabDisch_Ferritin                          float64
# pre_internal_LabDisch_Ferritin_Hours                    float64
# pre_internal_LabDisch_Ferritin_AbnormalityCode            int64
# pre_internal_LabDisch_Bilirubin                           int64
# pre_internal_LabDisch_Bilirubin_Hours                   float64
# pre_internal_LabDisch_Bilirubin_AbnormalityCode           int64
# pre_internal_LabDisch_AST                               float64
# pre_internal_LabDisch_AST_Hours                         float64
# pre_internal_LabDisch_AST_AbnormalityCode                 int64
# pre_internal_LabDisch_ALT                                 int64
# pre_internal_LabDisch_ALT_Hours                         float64
# pre_internal_LabDisch_ALT_AbnormalityCode                 int64
# pre_internal_LabDisch_ALP                               float64
# pre_internal_LabDisch_ALP_Hours                         float64
# pre_internal_LabDisch_ALP_AbnormalityCode                 int64
# pre_internal_LabDisch_GGT                               float64
# pre_internal_LabDisch_GGT_Hours                         float64
# pre_internal_LabDisch_GGT_AbnormalityCode                 int64
# pre_internal_LabDisch_Alb                               float64
# pre_internal_LabDisch_Alb_Hours                         float64
# pre_internal_LabDisch_Alb_AbnormalityCode                 int64
# pre_internal_LabDisch_UricAcid                          float64
# pre_internal_LabDisch_UricAcid_Hours                    float64
# pre_internal_LabDisch_UricAcid_AbnormalityCode            int64
# pre_internal_ECG                                          int64
# pre_internal_ECG_HR                                     float64
# pre_internal_ECG_Rhythm                                   int64
# pre_internal_ECG_QRS_Duration                           float64
# pre_internal_ECG_QRS_Morphology                           int64
# pre_internal_ECG_AV_Block                                 int64
# pre_internal_ECG_PR_Interval                            float64
# pre_internal_ECG_QT_Interval                            float64
# pre_internal_Imaging                                      int64
# pre_internal_Imaging_TechnicalDifficulty                float64
# pre_internal_Imaging_EF_Modality                          int64
# pre_internal_Imaging_LVEF                               float64
# pre_internal_Imaging_LVEF_Date                            int64
# pre_internal_Imaging_LVEF_Year                          float64
# pre_internal_Imaging_DiastolicDysfunction                 int64
# pre_internal_Imaging_MR                                   int64
# pre_internal_Imaging_AS                                   int64
# pre_internal_Imaging_OtherValveDisease                  float64
# pre_internal_AdmissionUnitCode                            int64
# pre_internal_DischargeUnitCode                            int64
# pre_internal_InpatientOrderSet                          float64
# pre_internal_HeartFailureTeachingRecord                   int64
# pre_internal_DischargeGuidelinesForHeartFailure           int64
# pre_internal_HeartFailureDischargeInstructions            int64
# pre_internal_DischargeMedRec                            float64
# pre_internal_DischargeRxGiven                           float64
# pre_internal_FollowUpAppointment                        float64
# pre_internal_DeathDate                                    int64
# pre_internal_DeathCause                                   int64
# pre_internal_ETL_Labs                                     int64
# pre_internal_ETL_Hx                                       int64
# pre_internal_ETL_ECG                                      int64
# pre_CSBC_pre_diag_date                                    int64
# pre_CSBC_pre_diag_flag                                  float64
# pre_CSBC_pre_PCI_date                                     int64
# pre_CSBC_pre_pci_flag                                   float64
# pre_CSBC_pre_CABG_date                                    int64
# pre_CSBC_pre_cabg_flag                                  float64
# pre_CSBC_pre_valve_date                                   int64
# pre_CSBC_pre_valve_flag                                 float64
# pre_CSBC_pre_ablation_date                                int64
# pre_CSBC_pre_ablation_flag                              float64
# pre_CSBC_pre_PM_date                                      int64
# pre_CSBC_pre_PM_flag                                    float64
# pre_CSBC_pre_ICD_date                                     int64
# pre_CSBC_pre_ICD_flag                                   float64
# pre_CSBC_pre_CRT_date                                     int64
# pre_CSBC_pre_CRT_flag                                   float64
# post_n_rehosp                                           float64
# post_total_LOS                                          float64
# post_rehosp_flag                                          int64
# post_latest_discharge                                     int64
# post_DIAG_CODE_1_1                                        int64
# post_DIAG_CODE_1_2                                        int64
# post_DIAG_CODE_1_3                                        int64
# post_DIAG_CODE_1_4                                        int64
# post_DIAG_CODE_1_5                                        int64
# post_DIAG_CODE_1_6                                        int64
# post_DIAG_CODE_1_7                                        int64
# post_DIAG_CODE_1_8                                        int64
# post_DIAG_CODE_1_9                                        int64
# post_DIAG_CODE_1_10                                       int64
# post_DIAG_CODE_1_11                                       int64
# post_DIAG_CODE_1_12                                       int64
# post_DIAG_CODE_1_13                                       int64
# post_DIAG_CODE_1_14                                       int64
# post_DIAG_CODE_1_15                                       int64
# post_DIAG_CODE_1_16                                       int64
# post_DIAG_CODE_1_17                                       int64
# post_DIAG_CODE_1_18                                       int64
# post_DIAG_CODE_1_19                                       int64
# post_DIAG_CODE_1_20                                       int64
# post_DIAG_CODE_1_21                                       int64
# post_DIAG_CODE_1_22                                       int64
# post_DIAG_CODE_1_23                                       int64
# post_DIAG_CODE_1_24                                       int64
# post_DIAG_CODE_1_25                                       int64
# post_DIAG_CODE_1_26                                       int64
# post_DIAG_CODE_1_27                                       int64
# post_DIAG_CODE_1_28                                       int64
# post_DIAG_CODE_1_29                                       int64
# post_DIAG_CODE_1_30                                       int64
# post_DIAG_CODE_1_31                                       int64
# post_DIAG_CODE_1_32                                       int64
# post_DIAG_CODE_1_33                                       int64
# post_DIAG_CODE_1_34                                       int64
# post_DIAG_CODE_1_35                                       int64
# post_DIAG_CODE_1_36                                       int64
# post_DIAG_CODE_1_37                                       int64
# post_DIAG_CODE_1_38                                       int64
# post_DIAG_CODE_1_39                                       int64
# post_DIAG_CODE_1_40                                       int64
# post_DIAG_CODE_1_41                                       int64
# post_DIAG_CODE_1_42                                       int64
# post_DIAG_CODE_1_43                                       int64
# post_DIAG_CODE_1_44                                       int64
# post_DIAG_CODE_1_45                                       int64
# post_DIAG_CODE_1_46                                       int64
# post_DIAG_CODE_1_47                                       int64
# post_DIAG_CODE_1_48                                       int64
# post_DIAG_CODE_1_49                                       int64
# post_DIAG_CODE_1_50                                       int64
# post_DIAG_CODE_1_51                                       int64
# post_DIAG_CODE_1_52                                       int64
# post_DIAG_CODE_1_53                                       int64
# post_DIAG_CODE_1_54                                       int64
# post_ADMISSION_DATE_1                                     int64
# post_ADMISSION_DATE_2                                     int64
# post_ADMISSION_DATE_3                                     int64
# post_ADMISSION_DATE_4                                     int64
# post_ADMISSION_DATE_5                                     int64
# post_ADMISSION_DATE_6                                     int64
# post_ADMISSION_DATE_7                                     int64
# post_ADMISSION_DATE_8                                     int64
# post_ADMISSION_DATE_9                                     int64
# post_ADMISSION_DATE_10                                    int64
# post_ADMISSION_DATE_11                                    int64
# post_ADMISSION_DATE_12                                    int64
# post_ADMISSION_DATE_13                                    int64
# post_ADMISSION_DATE_14                                    int64
# post_ADMISSION_DATE_15                                    int64
# post_ADMISSION_DATE_16                                    int64
# post_ADMISSION_DATE_17                                    int64
# post_ADMISSION_DATE_18                                    int64
# post_ADMISSION_DATE_19                                    int64
# post_ADMISSION_DATE_20                                    int64
# post_ADMISSION_DATE_21                                    int64
# post_ADMISSION_DATE_22                                    int64
# post_ADMISSION_DATE_23                                    int64
# post_ADMISSION_DATE_24                                    int64
# post_ADMISSION_DATE_25                                    int64
# post_ADMISSION_DATE_26                                    int64
# post_ADMISSION_DATE_27                                    int64
# post_ADMISSION_DATE_28                                    int64
# post_ADMISSION_DATE_29                                    int64
# post_ADMISSION_DATE_30                                    int64
# post_ADMISSION_DATE_31                                    int64
# post_ADMISSION_DATE_32                                    int64
# post_ADMISSION_DATE_33                                    int64
# post_ADMISSION_DATE_34                                    int64
# post_ADMISSION_DATE_35                                    int64
# post_ADMISSION_DATE_36                                    int64
# post_ADMISSION_DATE_37                                    int64
# post_ADMISSION_DATE_38                                    int64
# post_ADMISSION_DATE_39                                    int64
# post_ADMISSION_DATE_40                                    int64
# post_ADMISSION_DATE_41                                    int64
# post_ADMISSION_DATE_42                                    int64
# post_ADMISSION_DATE_43                                    int64
# post_ADMISSION_DATE_44                                    int64
# post_ADMISSION_DATE_45                                    int64
# post_ADMISSION_DATE_46                                    int64
# post_ADMISSION_DATE_47                                    int64
# post_ADMISSION_DATE_48                                    int64
# post_ADMISSION_DATE_49                                    int64
# post_ADMISSION_DATE_50                                    int64
# post_ADMISSION_DATE_51                                    int64
# post_ADMISSION_DATE_52                                    int64
# post_ADMISSION_DATE_53                                    int64
# post_ADMISSION_DATE_54                                    int64
# post_INST_CODE_1                                        float64
# post_INST_CODE_2                                        float64
# post_INST_CODE_3                                        float64
# post_INST_CODE_4                                        float64
# post_INST_CODE_5                                        float64
# post_INST_CODE_6                                        float64
# post_INST_CODE_7                                        float64
# post_INST_CODE_8                                        float64
# post_INST_CODE_9                                        float64
# post_INST_CODE_10                                       float64
# post_INST_CODE_11                                       float64
# post_INST_CODE_12                                       float64
# post_INST_CODE_13                                       float64
# post_INST_CODE_14                                       float64
# post_INST_CODE_15                                       float64
# post_INST_CODE_16                                       float64
# post_INST_CODE_17                                       float64
# post_INST_CODE_18                                       float64
# post_INST_CODE_19                                       float64
# post_INST_CODE_20                                       float64
# post_INST_CODE_21                                       float64
# post_INST_CODE_22                                       float64
# post_INST_CODE_23                                       float64
# post_INST_CODE_24                                       float64
# post_INST_CODE_25                                       float64
# post_INST_CODE_26                                       float64
# post_INST_CODE_27                                       float64
# post_INST_CODE_28                                       float64
# post_INST_CODE_29                                       float64
# post_INST_CODE_30                                       float64
# post_INST_CODE_31                                       float64
# post_INST_CODE_32                                       float64
# post_INST_CODE_33                                       float64
# post_INST_CODE_34                                       float64
# post_INST_CODE_35                                       float64
# post_INST_CODE_36                                       float64
# post_INST_CODE_37                                       float64
# post_INST_CODE_38                                       float64
# post_INST_CODE_39                                       float64
# post_INST_CODE_40                                       float64
# post_INST_CODE_41                                       float64
# post_INST_CODE_42                                       float64
# post_INST_CODE_43                                       float64
# post_INST_CODE_44                                       float64
# post_INST_CODE_45                                       float64
# post_INST_CODE_46                                       float64
# post_INST_CODE_47                                       float64
# post_INST_CODE_48                                       float64
# post_INST_CODE_49                                       float64
# post_INST_CODE_50                                       float64
# post_INST_CODE_51                                       float64
# post_INST_CODE_52                                       float64
# post_INST_CODE_53                                       float64
# post_INST_CODE_54                                       float64
# post_hosp_name_1                                          int64
# post_hosp_name_2                                          int64
# post_hosp_name_3                                          int64
# post_hosp_name_4                                          int64
# post_hosp_name_5                                          int64
# post_hosp_name_6                                          int64
# post_hosp_name_7                                          int64
# post_hosp_name_8                                          int64
# post_hosp_name_9                                          int64
# post_hosp_name_10                                         int64
# post_hosp_name_11                                         int64
# post_hosp_name_12                                         int64
# post_hosp_name_13                                         int64
# post_hosp_name_14                                         int64
# post_hosp_name_15                                         int64
# post_hosp_name_16                                         int64
# post_hosp_name_17                                         int64
# post_hosp_name_18                                         int64
# post_hosp_name_19                                         int64
# post_hosp_name_20                                         int64
# post_hosp_name_21                                         int64
# post_hosp_name_22                                         int64
# post_hosp_name_23                                         int64
# post_hosp_name_24                                         int64
# post_hosp_name_25                                         int64
# post_hosp_name_26                                         int64
# post_hosp_name_27                                         int64
# post_hosp_name_28                                         int64
# post_hosp_name_29                                         int64
# post_hosp_name_30                                         int64
# post_hosp_name_31                                         int64
# post_hosp_name_32                                         int64
# post_hosp_name_33                                         int64
# post_hosp_name_34                                         int64
# post_hosp_name_35                                         int64
# post_hosp_name_36                                         int64
# post_hosp_name_37                                         int64
# post_hosp_name_38                                         int64
# post_hosp_name_39                                         int64
# post_hosp_name_40                                         int64
# post_hosp_name_41                                         int64
# post_hosp_name_42                                         int64
# post_hosp_name_43                                         int64
# post_hosp_name_44                                         int64
# post_hosp_name_45                                         int64
# post_hosp_name_46                                         int64
# post_hosp_name_47                                         int64
# post_hosp_name_48                                         int64
# post_hosp_name_49                                         int64
# post_hosp_name_50                                         int64
# post_hosp_name_51                                         int64
# post_hosp_name_52                                         int64
# post_hosp_name_53                                         int64
# post_hosp_name_54                                         int64
# post_LOS_1                                              float64
# post_LOS_2                                              float64
# post_LOS_3                                              float64
# post_LOS_4                                              float64
# post_LOS_5                                              float64
# post_LOS_6                                              float64
# post_LOS_7                                              float64
# post_LOS_8                                              float64
# post_LOS_9                                              float64
# post_LOS_10                                             float64
# post_LOS_11                                             float64
# post_LOS_12                                             float64
# post_LOS_13                                             float64
# post_LOS_14                                             float64
# post_LOS_15                                             float64
# post_LOS_16                                             float64
# post_LOS_17                                             float64
# post_LOS_18                                             float64
# post_LOS_19                                             float64
# post_LOS_20                                             float64
# post_LOS_21                                             float64
# post_LOS_22                                             float64
# post_LOS_23                                             float64
# post_LOS_24                                             float64
# post_LOS_25                                             float64
# post_LOS_26                                             float64
# post_LOS_27                                             float64
# post_LOS_28                                             float64
# post_LOS_29                                             float64
# post_LOS_30                                             float64
# post_LOS_31                                             float64
# post_LOS_32                                             float64
# post_LOS_33                                             float64
# post_LOS_34                                             float64
# post_LOS_35                                             float64
# post_LOS_36                                             float64
# post_LOS_37                                             float64
# post_LOS_38                                             float64
# post_LOS_39                                             float64
# post_LOS_40                                             float64
# post_LOS_41                                             float64
# post_LOS_42                                             float64
# post_LOS_43                                             float64
# post_LOS_44                                             float64
# post_LOS_45                                             float64
# post_LOS_46                                             float64
# post_LOS_47                                             float64
# post_LOS_48                                             float64
# post_LOS_49                                             float64
# post_LOS_50                                             float64
# post_LOS_51                                             float64
# post_LOS_52                                             float64
# post_LOS_53                                             float64
# post_LOS_54                                             float64
# post_Death_date                                           int64
# pre_internal_Ramipril Dose                              float64
# pre_internal_Perindopril Dose                           float64
# pre_internal_Lisinopril Dose                            float64
# pre_internal_Enalapril Dose                             float64
# pre_internal_Captopril Dose                             float64
# pre_internal_Trandolapril Dose                          float64
# pre_internal_Quinapril Dose                             float64
# pre_internal_Benazepril Dose                            float64
# pre_internal_Fosinopril Dose                            float64
# pre_internal_Cilazapril Dose                            float64
# pre_internal_Candesartan Dose                           float64
# pre_internal_Valsartan Dose                             float64
# pre_internal_Losartan Dose                              float64
# pre_internal_Irbesartan Dose                            float64
# pre_internal_Telmisartan Dose                           float64
# pre_internal_Carvedilol Dose                            float64
# pre_internal_Bisoprolol Dose                            float64
# pre_internal_Metoprolol Dose                            float64
# pre_internal_Nebivolol Dose                             float64
# pre_internal_Atenolol Dose                              float64
# pre_internal_Sotalol Dose                               float64
# pre_internal_Propranalol Dose                           float64
# pre_internal_Nadolol Dose                               float64
# pre_internal_Acebutolol Dose                            float64
# pre_internal_Labetolol Dose                             float64
# pre_internal_Pindolol Dose                              float64
# pre_internal_Timolol Dose                               float64
# pre_internal_Spironolactone Dose                        float64
# pre_internal_Eplerenone Dose                            float64
# pre_internal_Furosemide Dose                            float64
# pre_internal_Butenamide Dose                            float64
# pre_internal_Torsemide Dose                             float64
# pre_internal_BNP                                        float64
# pre_internal_Troponin                                   float64
# post_ADMISSION_DATE_DAY_1                               float64
# post_ADMISSION_DATE_MONTH_1                             float64
# post_Discharge_Day_1                                    float64
# post_Discharge_Month_1                                  float64
# post_ADMISSION_DATE_DAY_2                               float64
# post_ADMISSION_DATE_MONTH_2                             float64
# post_Discharge_Day_2                                    float64
# post_Discharge_Month_2                                  float64
# post_ADMISSION_DATE_DAY_3                               float64
# post_ADMISSION_DATE_MONTH_3                             float64
# post_Discharge_Day_3                                    float64
# post_Discharge_Month_3                                  float64
# post_ADMISSION_DATE_DAY_4                               float64
# post_ADMISSION_DATE_MONTH_4                             float64
# post_Discharge_Day_4                                    float64
# post_Discharge_Month_4                                  float64
# post_ADMISSION_DATE_DAY_5                               float64
# post_ADMISSION_DATE_MONTH_5                             float64
# post_Discharge_Day_5                                    float64
# post_Discharge_Month_5                                  float64
# post_ADMISSION_DATE_DAY_6                               float64
# post_ADMISSION_DATE_MONTH_6                             float64
# post_Discharge_Day_6                                    float64
# post_Discharge_Month_6                                  float64
# post_ADMISSION_DATE_DAY_7                               float64
# post_ADMISSION_DATE_MONTH_7                             float64
# post_Discharge_Day_7                                    float64
# post_Discharge_Month_7                                  float64
# post_ADMISSION_DATE_DAY_8                               float64
# post_ADMISSION_DATE_MONTH_8                             float64
# post_Discharge_Day_8                                    float64
# post_Discharge_Month_8                                  float64
# post_ADMISSION_DATE_DAY_9                               float64
# post_ADMISSION_DATE_MONTH_9                             float64
# post_Discharge_Day_9                                    float64
# post_Discharge_Month_9                                  float64
# post_ADMISSION_DATE_DAY_10                              float64
# post_ADMISSION_DATE_MONTH_10                            float64
# post_Discharge_Day_10                                   float64
# post_Discharge_Month_10                                 float64
# post_ADMISSION_DATE_DAY_11                              float64
# post_ADMISSION_DATE_MONTH_11                            float64
# post_Discharge_Day_11                                   float64
# post_Discharge_Month_11                                 float64
# post_ADMISSION_DATE_DAY_12                              float64
# post_ADMISSION_DATE_MONTH_12                            float64
# post_Discharge_Day_12                                   float64
# post_Discharge_Month_12                                 float64
# post_ADMISSION_DATE_DAY_13                              float64
# post_ADMISSION_DATE_MONTH_13                            float64
# post_Discharge_Day_13                                   float64
# post_Discharge_Month_13                                 float64
# post_ADMISSION_DATE_DAY_14                              float64
# post_ADMISSION_DATE_MONTH_14                            float64
# post_Discharge_Day_14                                   float64
# post_Discharge_Month_14                                 float64
# post_ADMISSION_DATE_DAY_15                              float64
# post_ADMISSION_DATE_MONTH_15                            float64
# post_Discharge_Day_15                                   float64
# post_Discharge_Month_15                                 float64
# post_ADMISSION_DATE_DAY_16                              float64
# post_ADMISSION_DATE_MONTH_16                            float64
# post_Discharge_Day_16                                   float64
# post_Discharge_Month_16                                 float64
# post_ADMISSION_DATE_DAY_17                              float64
# post_ADMISSION_DATE_MONTH_17                            float64
# post_Discharge_Day_17                                   float64
# post_Discharge_Month_17                                 float64
# post_ADMISSION_DATE_DAY_18                              float64
# post_ADMISSION_DATE_MONTH_18                            float64
# post_Discharge_Day_18                                   float64
# post_Discharge_Month_18                                 float64
# post_ADMISSION_DATE_DAY_19                              float64
# post_ADMISSION_DATE_MONTH_19                            float64
# post_Discharge_Day_19                                   float64
# post_Discharge_Month_19                                 float64
# post_ADMISSION_DATE_DAY_20                              float64
# post_ADMISSION_DATE_MONTH_20                            float64
# post_Discharge_Day_20                                   float64
# post_Discharge_Month_20                                 float64
# post_ADMISSION_DATE_DAY_21                              float64
# post_ADMISSION_DATE_MONTH_21                            float64
# post_Discharge_Day_21                                   float64
# post_Discharge_Month_21                                 float64
# post_ADMISSION_DATE_DAY_22                              float64
# post_ADMISSION_DATE_MONTH_22                            float64
# post_Discharge_Day_22                                   float64
# post_Discharge_Month_22                                 float64
# post_ADMISSION_DATE_DAY_23                              float64
# post_ADMISSION_DATE_MONTH_23                            float64
# post_Discharge_Day_23                                   float64
# post_Discharge_Month_23                                 float64
# post_ADMISSION_DATE_DAY_24                              float64
# post_ADMISSION_DATE_MONTH_24                            float64
# post_Discharge_Day_24                                   float64
# post_Discharge_Month_24                                 float64
# post_ADMISSION_DATE_DAY_25                              float64
# post_ADMISSION_DATE_MONTH_25                            float64
# post_Discharge_Day_25                                   float64
# post_Discharge_Month_25                                 float64
# post_ADMISSION_DATE_DAY_26                              float64
# post_ADMISSION_DATE_MONTH_26                            float64
# post_Discharge_Day_26                                   float64
# post_Discharge_Month_26                                 float64
# post_ADMISSION_DATE_DAY_27                              float64
# post_ADMISSION_DATE_MONTH_27                            float64
# post_Discharge_Day_27                                   float64
# post_Discharge_Month_27                                 float64
# post_ADMISSION_DATE_DAY_28                              float64
# post_ADMISSION_DATE_MONTH_28                            float64
# post_Discharge_Day_28                                   float64
# post_Discharge_Month_28                                 float64
# post_ADMISSION_DATE_DAY_29                              float64
# post_ADMISSION_DATE_MONTH_29                            float64
# post_Discharge_Day_29                                   float64
# post_Discharge_Month_29                                 float64
# post_ADMISSION_DATE_DAY_30                              float64
# post_ADMISSION_DATE_MONTH_30                            float64
# post_Discharge_Day_30                                   float64
# post_Discharge_Month_30                                 float64
# post_ADMISSION_DATE_DAY_31                              float64
# post_ADMISSION_DATE_MONTH_31                            float64
# post_Discharge_Day_31                                   float64
# post_Discharge_Month_31                                 float64
# post_ADMISSION_DATE_DAY_32                              float64
# post_ADMISSION_DATE_MONTH_32                            float64
# post_Discharge_Day_32                                   float64
# post_Discharge_Month_32                                 float64
# post_ADMISSION_DATE_DAY_33                              float64
# post_ADMISSION_DATE_MONTH_33                            float64
# post_Discharge_Day_33                                   float64
# post_Discharge_Month_33                                 float64
# post_ADMISSION_DATE_DAY_34                              float64
# post_ADMISSION_DATE_MONTH_34                            float64
# post_Discharge_Day_34                                   float64
# post_Discharge_Month_34                                 float64
# post_ADMISSION_DATE_DAY_35                              float64
# post_ADMISSION_DATE_MONTH_35                            float64
# post_Discharge_Day_35                                   float64
# post_Discharge_Month_35                                 float64
# post_ADMISSION_DATE_DAY_36                              float64
# post_ADMISSION_DATE_MONTH_36                            float64
# post_Discharge_Day_36                                   float64
# post_Discharge_Month_36                                 float64
# post_ADMISSION_DATE_DAY_37                              float64
# post_ADMISSION_DATE_MONTH_37                            float64
# post_Discharge_Day_37                                   float64
# post_Discharge_Month_37                                 float64
# post_ADMISSION_DATE_DAY_38                              float64
# post_ADMISSION_DATE_MONTH_38                            float64
# post_Discharge_Day_38                                   float64
# post_Discharge_Month_38                                 float64
# post_ADMISSION_DATE_DAY_39                              float64
# post_ADMISSION_DATE_MONTH_39                            float64
# post_Discharge_Day_39                                   float64
# post_Discharge_Month_39                                 float64
# post_ADMISSION_DATE_DAY_40                              float64
# post_ADMISSION_DATE_MONTH_40                            float64
# post_Discharge_Day_40                                   float64
# post_Discharge_Month_40                                 float64
# post_ADMISSION_DATE_DAY_41                              float64
# post_ADMISSION_DATE_MONTH_41                            float64
# post_Discharge_Day_41                                   float64
# post_Discharge_Month_41                                 float64
# post_ADMISSION_DATE_DAY_42                              float64
# post_ADMISSION_DATE_MONTH_42                            float64
# post_Discharge_Day_42                                   float64
# post_Discharge_Month_42                                 float64
# post_ADMISSION_DATE_DAY_43                              float64
# post_ADMISSION_DATE_MONTH_43                            float64
# post_Discharge_Day_43                                   float64
# post_Discharge_Month_43                                 float64
# post_ADMISSION_DATE_DAY_44                              float64
# post_ADMISSION_DATE_MONTH_44                            float64
# post_Discharge_Day_44                                   float64
# post_Discharge_Month_44                                 float64
# post_ADMISSION_DATE_DAY_45                              float64
# post_ADMISSION_DATE_MONTH_45                            float64
# post_Discharge_Day_45                                   float64
# post_Discharge_Month_45                                 float64
# post_ADMISSION_DATE_DAY_46                              float64
# post_ADMISSION_DATE_MONTH_46                            float64
# post_Discharge_Day_46                                   float64
# post_Discharge_Month_46                                 float64
# post_ADMISSION_DATE_DAY_47                              float64
# post_ADMISSION_DATE_MONTH_47                            float64
# post_Discharge_Day_47                                   float64
# post_Discharge_Month_47                                 float64
# post_ADMISSION_DATE_DAY_48                              float64
# post_ADMISSION_DATE_MONTH_48                            float64
# post_Discharge_Day_48                                   float64
# post_Discharge_Month_48                                 float64
# post_ADMISSION_DATE_DAY_49                              float64
# post_ADMISSION_DATE_MONTH_49                            float64
# post_Discharge_Day_49                                   float64
# post_Discharge_Month_49                                 float64
# post_ADMISSION_DATE_DAY_50                              float64
# post_ADMISSION_DATE_MONTH_50                            float64
# post_Discharge_Day_50                                   float64
# post_Discharge_Month_50                                 float64
# post_ADMISSION_DATE_DAY_51                              float64
# post_ADMISSION_DATE_MONTH_51                            float64
# post_Discharge_Day_51                                   float64
# post_Discharge_Month_51                                 float64
# post_ADMISSION_DATE_DAY_52                              float64
# post_ADMISSION_DATE_MONTH_52                            float64
# post_Discharge_Day_52                                   float64
# post_Discharge_Month_52                                 float64
# post_ADMISSION_DATE_DAY_53                              float64
# post_ADMISSION_DATE_MONTH_53                            float64
# post_Discharge_Day_53                                   float64
# post_Discharge_Month_53                                 float64
# post_ADMISSION_DATE_DAY_54                              float64
# post_ADMISSION_DATE_MONTH_54                            float64
# post_Discharge_Day_54                                   float64
# post_Discharge_Month_54                                 float64
# post_Time_to_death                                      float64
# post_Death_30                                             int64
# post_Death_60                                             int64
# post_Death_90                                             int64
# post_Death_120                                            int64
# post_Death_180                                            int64
# dtype: object

# %%
#Define functions for training and testing

# %pip install shap
import shap # v0.40.0
# shap.initjs()
from sklearn.impute import SimpleImputer
from sklearn.impute import KNNImputer
from sklearn.inspection import permutation_importance
def model_train(m,parameters,is_tree=False,is_rf=False,time=None):
    
    y = df[('post_Death_'+str(time))].values
    x_data = df_factorized.drop(df_factorized.filter(regex="post"),axis=1)
    #x = (x_data - np.min(x_data)) / (np.max(x_data) - np.min(x_data)).values
#     print("inf columns ", x_data.columns.to_series()[np.isinf(x_data).any()])
#     print('null columns ', x_data.isna().sum())
    x = x_data
    
    #output of this function
    cf=[]
    
    #feature importances
    fis=[]
    
    #3 runs of cross-validation
    for rs in [1,2,3]:
        #8-fold cross validation
        skf = StratifiedKFold(n_splits=8,shuffle=True,random_state=rs)
        skf.get_n_splits(x, y)
        for train_index, test_index in skf.split(np.zeros(x.shape[0]), y):
            print(train_index)
            x_train, x_test = x.iloc[train_index,:], x.iloc[test_index,:]
            y_train, y_test = y[train_index], y[test_index]


            #
            empty_train_columns =  []
            for col in x_train.columns.values:
                # all the values for this feature are null
                if sum(x_train[col].isnull()) == x_train.shape[0]:
                    empty_train_columns.append(col)
            imputed_train_columns=[c for c in x_train.columns if c not in empty_train_columns]
    #         x_train = x_train.dropna(axis=1,how='all').values
    
#             empty_test_columns =  []
#             for col in x_test.columns.values:
#                 # all the values for this feature are null
#                 if sum(x_test[col].isnull()) == x_test.shape[0]:
#                     empty_test_columns.append(col)
#             imputed_test_columns=[c for c in x_test.columns if c not in empty_test_columns]
            
            print('empty training columns - ', empty_train_columns)
#             print(empty_test_columns)
            #impute missing
            imp_knn = KNNImputer(missing_values=np.nan)
            
            

            imp_knn_x_train=pd.DataFrame(imp_knn.fit_transform(x_train),index=x_train.index,columns=imputed_train_columns)
            imp_knn_x_test=pd.DataFrame(imp_knn.transform(x_test),index=x_test.index,columns=imputed_train_columns)

            imp_mean = SimpleImputer(missing_values=np.nan, strategy='median')

            imp_mean_x_train=pd.DataFrame(imp_mean.fit_transform(x_train),index=x_train.index,columns=imputed_train_columns)
            imp_mean_x_test=pd.DataFrame(imp_mean.transform(x_test),index=x_test.index,columns=imputed_train_columns)

    #         print("Imputated training data - iron lvl",imp_knn_x_train['LabAdm_Iron'])
    #         print(x_train['LabAdm_Iron'])
    #         print(imp_mean_x_train.shape)

            for col in miss_knn_columns:
                x_train[col]=imp_knn_x_train[col]
                x_test[col]=imp_knn_x_test[col]
                
                #check if there are null values after imputing. should ideally not run
                if pd.isnull(x_train[col]).sum() > 0:
                    print(col,x_train.shape)
                    print('Null values for col, ',col,' are',pd.isnull(x_train[col]).sum())
                    print(x_train[col])
            for col in miss_mean_columns:
                x_train[col]=imp_mean_x_train[col]
                x_test[col]=imp_mean_x_test[col]
    #         print(x_train.shape)
    #         print(pd.isnull(x_train).sum())
    #         print(pd.isnull(imp_mean_x_train).sum())

        #smote
            over = SMOTE()
            under = RandomUnderSampler()
            steps = [('o', over),('u',under)]
            pipeline = Pipeline(steps=steps)
#             print(x_train.isna().sum())
            x_train, y_train = pipeline.fit_resample(x_train, y_train)

        #model fit and prediction
        #create model
            model = clone(m)
        #fit

            clf = GridSearchCV(model, parameters,cv=5, n_jobs=4)
            clf.fit(x_train, y_train)


            model = clf.best_estimator_
            
    #         #shap feature importance - runs too slow so it is commented out
    #         import shap
    #         explainer = shap.KernelExplainer(model.predict,x_train)
    #         shap_test = explainer.shap_values(x_test,n_samples=1000)
    #         print(f"Shap values length: {len(shap_test)}\n")
    #         print(f"Sample shap value:\n{shap_test[0]}")
    #         shap_df = pd.DataFrame(shap_test.values, 
    #                        columns=shap_test.feature_names, 
    #                        index=x_test.index)
    #         print(np.isclose(model.predict(x_test), explainer.expected_value[0] + shap_df.sum(axis=1)))

    #         columns = shap_df.apply(np.abs).mean()\
    #                          .sort_values(ascending=False).index
    #         fig, ax = plt.subplots(1, 2, figsize=(11,4))
    #         sns.barplot(data=shap_df[columns].apply(np.abs), orient='h', 
    #                     ax=ax[0])
    #         ax[0].set_title("Mean absolute shap value")
    #         sns.boxplot(data=shap_df[columns], orient='h', ax=ax[1])
    #         ax[1].set_title("Distribution of shap values");
    #         plt.show()

            result = permutation_importance(model, x_test, y_test, n_repeats=10, random_state=42, n_jobs=2)
            feature_importances = pd.DataFrame(result.importances_mean, index =x_test.columns,  columns=['importance']).sort_values('importance', ascending=False)

            print(feature_importances.head(20))
            fis.append(feature_importances)
    #         sorted_idx = result.importances_mean.argsort()
    #         fig, ax = plt.subplots()
    #         ax.boxplot(
    #             result.importances[sorted_idx].T, vert=False, labels=x_test.columns[sorted_idx]
    #         )
    #         ax.set_title("Permutation Importances (test set)")
    #         fig.tight_layout()
    #         plt.show()
    #     check common entries between x_train and x_test
    #         crs=[]
    #         print('common rows')
    #         for row in x_test:
    # #             print(row)
    #             cr = np.where((x_train == row).all(axis=1))
    #             if len(cr)>0:
    #                 crs.append(cr)
    # #             print(cr[0])
    # #             print(x_train[cr[0]])
    #         print(crs)

        #check duplicates for x_train
    #         num_dups=(x_train[:, np.newaxis] == x_train).all(axis=2).sum(axis=1)
    #         print('Duplicates ' ,np.where((num_dups>1)))

        #predict
            y_pred = clf.predict(x_test)
            matrix=confusion_matrix(y_test,y_pred)
            cf.append(matrix)
            print('Best params')
            print(clf.best_estimator_.get_params())
            print("Accuracy: ",(np.trace(matrix))/matrix.sum()*100)
    df_concat = pd.concat(fis)
    print(df_concat.groupby(level=0).mean().sort_values('importance', ascending=False))
    cf.append(df_concat.groupby(level=0).mean().sort_values('importance', ascending=False))
    return cf


def output_metrics(matrices,fis):
    average_matrix=np.mean(matrices,axis=0)
    class_accs = []
    ov_accs=[]
    for matrix in matrices:
        c = []
        ov_acc = (np.trace(matrix))/matrix.sum()*100
        ov_accs.append(ov_acc)
        for i in range(2):
            c.append((matrix[i][i]/matrix[i].sum()*100))
        class_accs.append(c)
    class_acc=np.mean(class_accs,axis=0)
    ov_accs=np.mean(ov_accs,axis=0)
    print("Overall Accuracy :",ov_accs)
    print("Class Accuracy for Not Death",class_acc[0])
    print("Class Accuracy for Death",class_acc[1])
    print('Feature Importances',fis.head(10))
    return([matrices,fis,ov_accs,class_acc[0],class_acc[1]])

def c_thresholds(fold_tests,fold_preds,t=0.5):
    matrices=[]
    print('fp length', len(fold_preds))
    for fold_ind in range(len(fold_tests)):
        fold_pred=fold_preds[fold_ind]
        fold_test=fold_tests[fold_ind]
        fp=[]
        for pred in fold_pred:
            print(pred[0]/pred.sum())
            if pred[0]/pred.sum() >= t:
                fp.append(0)
            else:
                fp.append(1)
        matrices.append(confusion_matrix(fold_test,fp))
#         print(fold_pred)
    return matrices

# %%
#Create an empty dataframe for training 


# print(days_to_check)



time_graphs={}
for d in days_to_check:
    time_graphs[d]={}

# %% [markdown]
# ### dummy classifier / baseline

# %%
# from sklearn.dummy import DummyClassifier
# parameters={}
# for d in days_to_check:
#     m = model_train(DummyClassifier(strategy="stratified"),parameters,time=d)
#     matrices=m[:-1]
#     fis=m[-1]
#     time_graphs[d]['Baseline']=output_metrics(matrices,fis)
#     with open('results/'+'Baseline'+'_'+str(d)+'_death_final_new.pkl', 'wb') as file:
#         # A new file will be created
#         pickle.dump(time_graphs[d]['Baseline'], file)

# %% [markdown]
# ### Gaussian Naive Bayes Model

# %%
# from sklearn.naive_bayes import GaussianNB
# parameters = {'var_smoothing': np.logspace(0,-9, num=100)}
# for d in days_to_check:
#     m = model_train(GaussianNB(),parameters,time=d)
#     matrices=m[:-1]
#     fis=m[-1]
#     time_graphs[d]['GNB']=output_metrics(matrices,fis)
# #     print(output_metrics(matrices,fis))
#     with open('results/'+'GNB'+'_'+str(d)+'_death_final_new.pkl', 'wb') as file:
#         # A new file will be created
#         pickle.dump(time_graphs[d]['GNB'], file)

# %% [markdown]
# ### K-Nearest Neighbors Classifier

# %%
# from sklearn.neighbors import KNeighborsClassifier
# parameters={'n_neighbors':[2,3,4,5,10]}
# for d in days_to_check:
#     m = model_train(KNeighborsClassifier(),parameters,time=d)
#     matrices=m[:-1]
#     fis=m[-1]
#     time_graphs[d]['KNN']=output_metrics(matrices,fis)
#     with open('results/'+'KNN'+'_'+str(d)+'_death_final_new.pkl', 'wb') as file:
#         # A new file will be created
#         pickle.dump(time_graphs[d]['KNN'], file)

# %% [markdown]
# ### Random Forest Classifier

# %%
# # with open('RF_death_final.pkl', 'rb') as file:
# #         time_graphs = pickle.load(file)
# from sklearn.ensemble import RandomForestClassifier
# parameters = {'max_depth':[1,5,10],
#               'n_estimators': [10,50,100],
#               'max_features': [1,3,5,'auto']
#              }
# for d in days_to_check:
#     m = model_train(RandomForestClassifier(),parameters,time=d)
#     matrices=m[:-1]
#     fis=m[-1]
#     time_graphs[d]['RF']=output_metrics(matrices,fis)
#     with open('results/'+'RF'+'_'+str(d)+'_death_final_new.pkl', 'wb') as file:
#         # A new file will be created
#         pickle.dump(time_graphs[d]['RF'], file)

# %%
time_graphs
# Out:
# {30: {}, 60: {}, 90: {}, 120: {}, 180: {}}
